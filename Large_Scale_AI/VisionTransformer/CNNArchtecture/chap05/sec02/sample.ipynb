# %%
import torch

x = torch.tensor([1, 2, 3])
y = torch.tensor([4, 5])

# 行列のインデックス順序 ('ij')
grid_x, grid_y = torch.meshgrid(x, y, indexing='ij')

print("grid_x:")
print(grid_x)
print("grid_y:")
print(grid_y)
# Out:
# grid_x:
# tensor([[1, 1],
#         [2, 2],
#         [3, 3]])
# grid_y:
# tensor([[4, 5],
#         [4, 5],
#         [4, 5]])
