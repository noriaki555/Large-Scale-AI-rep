# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import ops

import numpy as np
import matplotlib.pyplot as plt

# %%
num_classes = 100 # クラス数(分類するカテゴリの数)
input_shape = (32, 32, 3) # 入力画像の形状(高さ,幅,チャンネル数)
patch_size = (2, 2) # パッチのサイズ(2x2ピクセル)
dropout_rate = 0.1 # ドロップアウト率
num_heads = 8 # ヘッドの数
embed_dim = 256  # パッチデータに埋め込む位置情報の次元数
num_mlp = 1024  # 全結合層のユニット数

qkv_bias = True  # クエリ,キー,バリューに変換する際に学習可能なバイアスを追加
window_size = 2 # ウィンドウのサイズ
shift_size = 1 # ウィンドウのシフト量

image_dimension = 32 # 初期画像サイズ
num_patch_x = input_shape[0] // patch_size[0] # パッチ数(高さ方向)
num_patch_y = input_shape[1] // patch_size[1] # パッチ数(幅方向)

learning_rate = 1e-3  # 学習率
batch_size = 64  # バッチサイズ
num_epochs = 300  # エポック数
validation_split = 0.1 # 検証用データの割合
weight_decay = 0.0001 # 重み減衰の割合（L2正則化の強さ）
# ラベル平滑化の係数。0から1の値を取り、1に近いほどラベルを平滑化する
label_smoothing = 0.1

# %%
# CIFAR-100データセットを読み込む
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
# 画像データを0.0-1.0の範囲に正規化
x_train, x_test = x_train / 255.0, x_test / 255.0
# トレーニングラベルをワンホットエンコーディングに変換
y_train = keras.utils.to_categorical(y_train, num_classes)
# テストラベルをワンホットエンコーディングに変換
y_test = keras.utils.to_categorical(y_test, num_classes)
# トレーニングデータのサンプル数を計算
num_train_samples = int(len(x_train) * (1 - validation_split))
# 検証データのサンプル数を計算
num_val_samples = len(x_train) - num_train_samples
# トレーニングデータをトレーニング用と検証用に分割
x_train, x_val = np.split(x_train, [num_train_samples])
# トレーニングラベルをトレーニング用と検証用に分割
y_train, y_val = np.split(y_train, [num_train_samples])
# トレーニングデータとラベルの形状を表示
print(f"x_train shape: {x_train.shape} --- y_train shape: {y_train.shape}")
# テストデータとラベルの形状を表示
print(f"x_test shape: {x_test.shape} --- y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# x_train shape: (45000, 32, 32, 3) --- y_train shape: (45000, 100)
# x_test shape: (10000, 32, 32, 3) --- y_test shape: (10000, 100)

# %%
def patch_extract(images):
    """ 画像データをサイズ2×2のパッチに分割する

    Args:
        images: データ拡張後の画像のテンソル:(bs, 32, 32, 3)
    Returns:
        パッチに分割後、再整形したテンソル
        (bs, 256(パッチ数), 12(パッチの次元数))
    """
    # バッチデータのサイズを取得(batch_size=128)
    batch_size = tf.shape(images)[0]
    # 入力画像からパッチを抽出
    # sizeオプションにパッチサイズ(2,2)を設定
    # 32×32×3を2×2のパッチに分割
    # 元の画像は高さ方向16、幅方向16に分割され、合計256個のパッチになる
    # パッチ1個あたりの特徴量次元は2×2×3(チャンネル)＝12
    # (bs, 32, 32, 3)--->(bs, 16, 16, 12)
    patches = tf.image.extract_patches(
        # データ拡張後の画像のテンソル
        images=images,
        # 抽出するパッチのサイズ(patch_size = (2, 2))を指定: (1, 2, 2, 1)
        sizes=(1, patch_size[0], patch_size[1], 1),
        # ストライドサイズはパッチサイズと同じ: 縦方向2、横方向2
        strides=(1, patch_size[0], patch_size[1], 1),
        rates=(1, 1, 1, 1), # サンプリングレート
        padding="VALID", # パディングは行わない
    )
    # パッチ1個当たりの次元数を取得(patch_dim=12)
    patch_dim = patches.shape[-1]
    # パッチの縦方向の数を取得(patch_num=16)
    patch_num = patches.shape[1]
    # (bs, パッチの数(patch_num * patch_num), patch_dim)の形状に再整形して返す
    # (bs, 256, 12)
    return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))

# %%
class PatchEmbedding(layers.Layer):
    """ 全結合層、Embedding層から成るブロックを定義するクラス
        位置情報の埋め込みを行う

    Attributes:
        num_patch: パッチの数
        proj(layers.Dense): パッチデータを拡張する全結合層
        pos_embed(ayers.Embedding): パッチの位置埋め込み層
    """
    def __init__(self, num_patch, embed_dim, **kwargs):
        """
        Args:
            num_patch: パッチの数(16*16=256)
            embed_dim: 埋め込み次元数(embed_dim = 64)
            **kwargs: その他のキーワード引数
        """
        super().__init__(**kwargs)
        # 画像1枚当たりのパッチ数を設定
        self.num_patch = num_patch
        # 位置情報を埋め込むためにチャンネル次元を拡張する全結合層
        # ユニット数: embed_dim = 64
        self.proj = layers.Dense(embed_dim)
        # エンベッディング(埋め込み)を行うレイヤー
        # input_dimの次元数に対して、output_dimの数だけ
        # 学習可能なパラメーターが作成される
        # 作成されるパラメーターテンソルの形状: (256, 64)
        # パラメーター数: 256*64=16,384
        self.pos_embed = layers.Embedding(
            input_dim=num_patch, # 入力の次元数(パッチの数(16*16=256))
            output_dim=embed_dim # 作成するエンベッディングベクトルの次元数(embed_dim = 64)
        )

    def call(self, patch):
        """ フォワードパス(順伝搬処理)

        Args:
            patch: パッチに分割後のテンソル(bs, num_patch(256), patch_dim(12))
        Returns:
            位置情報埋め込み後のテンソル(bs, num_patch(256), embed_dim(64))
        """
        # Embeddingレイヤーのパラメーター値を取得するためのインデックスとして
        # 要素が[0, 1, 2, ..., 255]、形状が(256,)の1階テンソルを作成
        pos = ops.arange(start=0, stop=self.num_patch)

        # パッチに分割後のテンソルをユニット数(64)の全結合層で
        # (bs, 256, 64)にチャンネル次元数を64に拡張
        #
        # Embeddingレイヤーにインデックスposを入力してパラメーター値を
        # 形状(256, 64)のテンソルとして取得
        #
        # 変換後の画像データ(bs, 256, 64)に対して、位置情報(256, 64)を加算
        # 戻り値のテンソルの形状: (bs, 256, 64)
        return self.proj(patch) + self.pos_embed(pos)

# %%
def window_partition(x, window_size):
    """ 入力画像をウィンドウに分割する
    Args:
        x: (bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64(チャンネル数))
        window_size(int): ウィンドウ1辺のサイズ(window_size = 2)

    Returns:
        ウィンドウに分割後の特徴マップ
        (bs * 8(高さ方向ウィンドウ数) * 8(幅方向ウィンドウ数),
        2(ウィンドウサイズ(高さ方向)), 2(ウインドウサイズ(幅方向)), 64)
    """
    # (bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64(チャンネル数))から
    # さ方向パッチ数、幅方向パッチ数、チャンネル数を取得
    _, height, width, channels = x.shape
    # 高さ方向のウィンドウ数を計算
    patch_num_y = height // window_size
    # 幅方向のウィンドウの数を計算
    patch_num_x = width // window_size

    # 入力画像xをウィンドウサイズに基づいて再整形する
    # 処理後の形状: (bs, 8, 2, 8, 2, 64)
    x = ops.reshape(
        x,  # 入力テンソル
        (
            -1,  # bs(バッチサイズ)はそのまま
            patch_num_y,  # 高さ方向のウィンドウ数
            window_size,  # ウィンドウの高さ方向のサイズ
            patch_num_x,  # 幅方向のウィンドウ数
            window_size,  # ウィンドウの幅方向のサイズ
            channels,  # チャンネル数
        ),
    )

    # テンソルxを
    # (bs, ウィンドウ数(高さ方向),
    #      ウィンドウ数(幅方向),
    #      ウィンドウサイズ(高さ方向),
    #      ウインドウサイズ(幅方向),
    #      チャンネル数)
    # の順に並べ換える。 処理後の形状: (bs, 8, 8, 2, 2, 64)
    x = ops.transpose(x, (0, 1, 3, 2, 4, 5))

    # 並べ換えた次元に沿ってテンソルを再整形(データを新しい形状に再配置)する
    # 形状: (bs * 8(高さ方向ウィンドウ数) * 8(幅方向ウィンドウ数),
    #        2(ウィンドウサイズ(高さ方向)), 2(ウインドウサイズ(幅方向)), 64)
    windows = ops.reshape(x, (-1, window_size, window_size, channels))
    return windows

# %%
def window_reverse(windows, window_size, height, width, channels):
    """ ウィンドウへの分割を解除して元の特徴マップの形状に戻す
    Args:
        windows: (bs * 8 * 8, 2, 2, 64)
        window_size(int): ウィンドウのサイズ(window_size = 2)
        height(int): 1画像当たりのパッチ数(16(高さ))
        width(int): 1画像当たりのパッチ数(16(幅))
        channels: チャンネル数(64)

    Returns:
        x: ウィンドウ分割を解除したテンソル
           (bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64(チャンネル数))
    """
    # 高さ方向のウィンドウ数を計算
    # patch_num_y  = 8
    patch_num_y = height // window_size
    # 幅方向のウィンドウの数を計算
    # patch_num_x = 8
    patch_num_x = width // window_size

    # 入力テンソルwindowsをウィンドウサイズに基づいて再整形する
    # (bs * 8 * 8, 2, 2, 64) -> (bs, 8, 8, 2, 2, 64)
    x = ops.reshape(
        windows,  # 入力テンソル
        (
            -1,  # 第1次元は自動計算
            patch_num_y,  # 高さ方向のウィンドウ数
            patch_num_x,  # 幅方向のウィンドウ数
            window_size,  # ウィンドウの高さ
            window_size,  # ウィンドウの幅
            channels,  # チャンネル数
        ),
    )

    # 転置して元の次元の並びに戻す
    # (bs, 8(ウィンドウ数-高さ), 2(サイズ-高さ), 8(ウィンドウ数-幅), 2(サイズ-幅), 64)
    x = ops.transpose(x, (0, 1, 3, 2, 4, 5))

    # ウィンドウ分割前の形状に再整形する
    # (bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64(チャンネル数))
    x = ops.reshape(x, (-1, height, width, channels))

    return x

# %%
class WindowAttention(layers.Layer):
    """ layers.Layerを継承したカスタムレイヤー
        W-MSA、SW-MSAベースのSelf-Attention機構を実装する

    Attributes:
        dim(int): 入力特徴量の次元数(位置情報の次元数(embed_dim = 64))
        window_size: ウィンドウの形状(高さ=2, 幅=2)
        num_heads: ヘッドの数(num_heads = 8)
        scale: クエリベクトルをスケーリングするための係数
        qkv: クエリ、キー、バリューを生成するための全結合層
        dropout: ドロップアウト率(dropout_rate = 0.06)
        proj: 出力を生成するための全結合層
    """
    def __init__(
        self,
        dim,
        window_size,
        num_heads,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        """
        Args:
            dim(int): 入力特徴量の次元数(位置情報の次元数(embed_dim = 64))
            window_size(tuple): ウィンドウの形状(2(高さ), 2(幅))
            num_heads(int): ヘッドの数(num_heads = 8)
            qkv_bias(bool): クエリ、キー、バリューにバイアスを追加するかどうか
                            (qkv_bias = True)
            dropout_rate(float): ドロップアウト率(dropout_rate = 0.06)
            **kwargs(dict): その他のキーワード引数
        """
        super().__init__(**kwargs)
        # 位置情報の次元数(embed_dim = 64))を入力特徴量の次元数として設定
        self.dim = dim
        # ウィンドウの形状(window_size(縦方向=7), window_size(行方向=7))を設定
        self.window_size = window_size
        # ヘッドの数(num_heads = 8)を設定
        self.num_heads = num_heads
        # クエリベクトルをスケーリングする係数を計算
        self.scale = (dim // num_heads) ** -0.5

        # クエリ、キー、バリューを生成する全結合層を作成
        # ユニット数: 入力次元数(64) * 3 = 192
        # バイアスを使用する
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        # ドロップアウト(dropout_rate = 0.06)レイヤーを作成
        self.dropout = layers.Dropout(dropout_rate)
        # 出力層を作成
        # ユニット数: 入力次元数=64
        self.proj = layers.Dense(dim)
        # ウィンドウ内パッチ間の相対位置の組み合わせを計算
        # (2 * 2 - 1) * (2 * 2 - 1) = 9
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )

        # 相対位置エンコーディングを学習するパラメーター(重み)を作成
        # テンソル形状: (9, 8)
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads), # パラメーターの形状: (9, 8)
            initializer=keras.initializers.Zeros(), # パラメーター値をゼロで初期化
            trainable=True, # パラメーター値を更新する
        )
        # ウィンドウの高さ方向の座標を生成
        # coords_h = [0 1]
        coords_h = np.arange(self.window_size[0])

        # ウィンドウの幅方向の座標を生成
        # coords_w = [0 1]
        coords_w = np.arange(self.window_size[1])
        # 座標のグリッドを生成
        # coords_matrix[0]: [[0, 0], [1, 1]]y座標(縦方向)の変化
        # coords_matrix[1]: [[0, 1], [0, 1]]x座標(横方向)の変化
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        # 座標のグリッドをスタック
        # coordsの形状: (2, 2, 2)
        coords = np.stack(coords_matrix)
        # coordsの形状を再整形する。-1は自動計算される次元のサイズ
        # (2, 2, 2)  --> (2, 4)
        coords_flatten = coords.reshape(2, -1)

        # 相対位置の計算
        # 各座標ペアについて、(x座標, y座標)の差を計算して、
        # ウィンドウ内のすべてのy座標の相対位置とx座標の相対位置を求める
        # relative_coordsの形状: (2, 4, 4)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        # 転置して(4, 4, 2)の形状にする
        # 最後の次元で(y座標の相対位置, x座標の相対位置)のように、相対位置のペアを作る
        relative_coords = relative_coords.transpose([1, 2, 0])
        # y座標の相対位置に1を加えることで、y座標の相対位置をすべて正の値にする
        relative_coords[:, :, 0] += self.window_size[0] - 1
        # x座標の相対位置に1を加えることで、x座標の相対位置をすべて正の値にする
        relative_coords[:, :, 1] += self.window_size[1] - 1
        # y座標の相対位置をスケーリング
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        # 最後の次元の(y座標の相対位置, x座標の相対値)の合計を求め、一意のインデックスを生成
        relative_position_index = relative_coords.sum(-1)
        # 相対位置インデックスを変数として保存
        self.relative_position_index = keras.Variable(
            initializer=relative_position_index,
            shape=relative_position_index.shape,
            dtype="int",
            trainable=False,
        )


    def call(self, x, mask=None):
        """ フォワードパスを設定

        Args:
            x: ウィンドウ分割後、再整形されたテンソル
               (bs * ウィンドウ数, ウィンドウ内パッチ数, チャンネル数)
               (bs * 8 * 8, 2 * 2, 64)
            mask: マスク(64, 4, 4)

        Returns:
            x_qkv: アテンション後の出力テンソル
        """
        # ウィンドウ内パッチ数(4)、チャンネル数(64)を取得
        _, size, channels = x.shape
        # チャンネル次元数をヘッドの数(num_heads = 8)で割ってヘッドごとの次元数を計算
        head_dim = channels // self.num_heads
        # クエリ、キー、バリューを生成するための全結合層でチャンネル次元数を拡張
        # ユニット数: チャンネル次元数(64) * 3 = 192
        # 出力: (bs * 8 * 8, 4(ウィンドウ内パッチ数), 192)
        x_qkv = self.qkv(x)

        # チャンネル次元数192を順次分割: 192 -> 3(q,k,v) -> ヘッド数(8) -> ヘッドサイズ(8)
        #(bs * 64(ウィンドウ数, 4(ウィンドウ内パッチ数),3(q,k,v),8(ヘッド数),8(ヘッドサイズ))
        x_qkv = ops.reshape(x_qkv, (-1, size, 3, self.num_heads, head_dim))
        # 第1次元をqkvにして、ヘッド(8)に分割
        # (3(q,k,v),bs*64(ウィンドウ数),8(ヘッド数),4(ウィンドウ内パッチ数),8(ヘッドサイズ))
        x_qkv = ops.transpose(x_qkv, (2, 0, 3, 1, 4))
        # クエリ、キー、バリューに分割
        # (bs * 64(ウィンドウ数, 8(ヘッド数), 4(ウィンドウ内パッチ数), 8(ヘッドサイズ))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]

        # クエリをスケーリング
        q = q * self.scale
        # キーを転置
        # (bs * 64(ウィンドウ数), 8(ヘッド数), 8(ヘッドサイズ), 4(ウィンドウ内パッチ数))
        k = ops.transpose(k, (0, 1, 3, 2))
        # 類似度スコアを計算
        # 第2次元はヘッドの数、第3次元と第4次元は、ウィンドウ内の
        # すべてのパッチの組み合わせによる類似度を示す
        # (bs * 16, 8(ヘッド数), 4, 4)
        attn = q @ k
        # ウィンドウ内のパッチ数を計算
        # num_window_elements = 4
        num_window_elements = self.window_size[0] * self.window_size[1]
        # 相対位置インデックスをフラット化
        # (4, 4) -> (16,)
        relative_position_index_flat = ops.reshape(self.relative_position_index, (-1,))
        # 相対位置エンコーディングを取得
        # (16(相対位置インデックスの数), 8(ヘッド数))
        relative_position_bias = ops.take(
            # 相対位置エンコーディングを学習するパラメーター(9, 8)
            self.relative_position_bias_table,
            # 相対位置インデックス(16,)
            relative_position_index_flat,
            # 第1次元に沿って収集する
            axis=0,
        )

        # 相対位置エンコーディングの形状を変換
        # (16(相対位置インデックスの数), 8(ヘッド数))
        #    -->(4(ウィンドウ内パッチ数), 4(ウィンドウ内パッチ数), 8(ヘッド数))
        relative_position_bias = ops.reshape(
            relative_position_bias,
            (num_window_elements, num_window_elements, -1),
        )
        # 次元の並びを入れ換える
        # (4, 4, 8) => (8, 4, 4)
        relative_position_bias = ops.transpose(relative_position_bias, (2, 0, 1))
        # アテンションスコアの計算
        # relative_position_biasの形状(1, 8, 4, 4)を(bs * 16, 8, 4, 4) に拡張し、
        # 類似度スコアに加算してアテンションスコアにする
        # attn形状: (bs * 16, 8(ヘッド数), 4, 4)
        attn = attn + ops.expand_dims(relative_position_bias, axis=0)

        # マスクの処理
        # マスクテンソルの形状: (64, 4, 4)
        if mask is not None:
            # マスクのウィンドウ数を取得(nW = 64)
            nW = mask.shape[0]
            # マスクテンソルの第2次元を追加し、さらに第1次元を追加:(1, 64, 1, 4, 4)
            # テンソルのデータ型をfloat型にキャスト
            mask_float = ops.cast(
                ops.expand_dims(ops.expand_dims(mask, axis=1), axis=0),
                "float32",
            )
            # アテンションスコアの形状を再整形する
            # (bs * 64, 8, 4, 4) --> (bs, 64, 8, 4, 4)
            # マスク(64, 4, 4)をブロードキャストで加算
            # attn形状: (bs, 64, 8, 4, 4)
            attn = ops.reshape(
                attn, (-1, nW, self.num_heads, size, size)
                ) + mask_float
            # attnの形状を変換
            # (bs, 64, 8, 4, 4) --> (bs * 64, 8, 4, 4)
            attn = ops.reshape(attn, (-1, self.num_heads, size, size))
            # ソフトマックスを適用
            # attn形状: (bs * 64, 64, 8, 4, 4)
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            # ソフトマックスを適用
            # attn形状: (bs * 64, 64, 8, 4, 4)
            attn = keras.activations.softmax(attn, axis=-1)

        # ドロップアウトを適用
        # attn形状: (bs * 64, 64, 8, 4, 4)
        attn = self.dropout(attn)
        # アテンションスコアにバリューを適用
        # 出力: (bs * 64, 8, 4, 8)
        x_qkv = attn @ v
        # x_qkvの次元の並びを変更
        # (bs * 64, 4, 8, 8)
        x_qkv = ops.transpose(x_qkv, (0, 2, 1, 3))
        # x_qkvを再整形
        # (bs * 64, 4, 64)
        x_qkv = ops.reshape(x_qkv, (-1, size, channels))
        # ユニット数64の全結合層に入力して出力を生成
        # (bs * 64, 4, 64)
        x_qkv = self.proj(x_qkv)
        # ドロップアウトを適用
        # (bs * 64, 4, 64)
        x_qkv = self.dropout(x_qkv)

        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    """ layers.Layerを継承したカスタムレイヤー

    ・パッチ分割後の画像データをウィンドウに分割
    ・各ウィンドウに対してW-MSA、SW-MSAによる自己注意機構を適用
    ・ウィンドウに分割されたテンソルを元の形状に戻した状態で
      MLP層を組み合わせて、画像の特徴抽出と表現を学習する

    Attributes:
        dim(int): 入力特徴量の次元数(位置情報の次元数(embed_dim = 64))
        num_patch(tuple): 1画像当たりのパッチ数(高さ=16, 幅=16))
        num_heads(int): ヘッドの数(num_heads = 8)
        window_size(int): ウィンドウのサイズ
        shift_size(int): ウィンドウのシフトサイズ(shift_size = 1)
        num_mlp(int): 全結合層のユニット数(num_mlp = 256)
        norm1: layers.LayerNormalization - 1つ目のLayer Normalization層。
        attn: WindowAttention - ウィンドウベースの自己注意層。
        drop_path: layers.Dropout - ドロップアウト層。
        norm2: layers.LayerNormalization - 2つ目のLayer Normalization層。
        mlp: keras.Sequential - MLP層のシーケンシャルモデル。
    """
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=7,
        shift_size=0,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        """
        Args:
            dim(int): 位置情報埋め込み後のチャンネル次元数(embed_dim = 64)
            num_patch(tuple): 1画像当たりのパッチ数(高さ=16, 幅=16)
            num_heads(int): ヘッドの数(num_heads = 8)
            window_size(int): ウィンドウのサイズ(window_size = 2)
            shift_size(int): ウィンドウのシフトサイズ(shift_size = 1)
            num_mlp(int): 全結合層のユニット数(num_mlp = 256)
            qkv_bias(bool): クエリ、キー、バリューにバイアスを追加するかどうか
                            (qkv_bias = True)
            dropout_rate(float): ドロップアウト率
            **kwargs(dict): その他のキーワード引数

        """
        super().__init__(**kwargs)
        # 位置情報埋め込み後のチャンネル次元数(embed_dim = 64)を
        # 入力特徴量の次元数として設定
        self.dim = dim
        # 1画像当たりのパッチ数(高さ=16, 幅=16)を設定
        self.num_patch = num_patch
        # ヘッドの数(num_heads = 8)を設定
        self.num_heads = num_heads
        # ウィンドウのサイズ(window_size = 2)を設定
        self.window_size = window_size
        # ウィンドウのシフトサイズ(shift_size = 1)を設定
        self.shift_size = shift_size
        # 全結合層のユニット数(num_mlp = 256)を設定
        self.num_mlp = num_mlp

        # 1つ目の正規化層を作成
        self.norm1 = layers.LayerNormalization(epsilon=1e-5)

        # WindowAttentionブロックを作成
        self.attn = WindowAttention(
            # 位置情報埋め込み後のチャンネル次元数(embed_dim = 64)
            dim,
            # ウィンドウの形状(window_size=2(高さ), window_size=2(幅))
            window_size=(self.window_size, self.window_size),
            # ヘッドの数(num_heads = 8)
            num_heads=num_heads,
            # クエリ、キー、バリューにバイアスを追加する(qkv_bias = True)
            qkv_bias=qkv_bias,
            # ドロップアウト率(dropout_rate = 0.06)
            dropout_rate=dropout_rate,
        )

        # ドロップアウト層を作成
        self.drop_path = layers.Dropout(dropout_rate)
        # 2つ目のLayer Normalization層を作成
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        # MLPを作成
        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp), # 全結合層(ユニット数:256)
                layers.Activation(keras.activations.gelu), # GELU関数を適用
                layers.Dropout(dropout_rate), # ドロップアウト
                layers.Dense(dim), # 全結合層(ユニット数:64)
                layers.Dropout(dropout_rate), # ドロップアウト
            ]
        )

        # パッチの数(高さ, 幅)がウィンドウの形状(高さ, 幅)より小さい場合
        if min(self.num_patch) < self.window_size:
            self.shift_size = 0  # シフトサイズを0に設定
            # ウィンドウサイズをパッチ数に合わせる
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        """ レイヤーにデータが最初に入力されたときに呼び出される

        Args:
            input_shape: 入力画像の形状(高さ,幅,チャンネル数)
                         (32, 32, 3)
        """
        # シフトサイズが0の場合
        if self.shift_size == 0:
            # マスクテンソルattn_maskをNoneに設定
            self.attn_mask = None
        else:
            # num_patch(高さ=16, 幅=16))からパッチの高さ方向の数と幅方向の数を取得
            height, width = self.num_patch
            # 高さ方向のスライスを作成
            # (window_size = 2, shift_size = 1と仮定)
            h_slices = (
                # 最初の領域: (0, －2)
                slice(0, -self.window_size),
                # 中間の領域: (-2, －1)
                slice(-self.window_size, -self.shift_size),
                # 最後の領域: (－1, None)
                slice(-self.shift_size, None),
            )
            # 幅方向のスライスを作成
            # (window_size = 2, shift_size = 1と仮定)
            w_slices = (
                # 最初の領域: (0, －2)
                slice(0, -self.window_size),
                # 中間の領域: (-2, －1)
                slice(-self.window_size, -self.shift_size),
                # 最後の領域: (－1, None)
                slice(-self.shift_size, None),
            )
            # マスク用のゼロ配列を作成
            # ・第1次元: バッチデータの次元（ここでは常に1）
            # ・第2次元: パッチの高さ方向の数
            # ・第3次元: パッチの幅方向の数
            # ・第4次元: チャンネル次元（ここでは常に1）
            mask_array = np.zeros((1, height, width, 1))

            # 各領域に割り当てる番号を保持するカウンター変数を0で初期化
            count = 0
            # 2重ループを使って2つのスライスを組み合わせ、
            # 各領域に対して番号を割り当てる
            for h in h_slices:  # 高さ方向のスライスに対して
                for w in w_slices:  # 幅方向のスライスに対して
                    mask_array[:, h, w, :] = count  # マスク配列にカウント値を設定
                    count += 1

            # マスク配列をテンソルに変換
            # (1, 16, 16, 1)
            mask_array = ops.convert_to_tensor(mask_array)
            # マスクテンソルをウィンドウに分割
            # (64, 2, 2, 1)
            mask_windows = window_partition(mask_array, self.window_size)
            # 再整形
            # (64, 4)
            mask_windows = ops.reshape(
                mask_windows, [-1, self.window_size * self.window_size]
            )

            # シフトした際のウィンドウ内パッチ間の相対的な位置関係の差分を計算
            # (64, 4, 4)
            attn_mask = ops.expand_dims(
                mask_windows, axis=1) - ops.expand_dims(mask_windows, axis=2)

            # 差がゼロではない領域(シフトによってウィンドウが重なる場合に
            # 発生する境界をまたぐ部分)を-100に設定
            attn_mask = ops.where(attn_mask != 0, -100.0, attn_mask)
            # 差がゼロの領域を0に設定
            attn_mask = ops.where(attn_mask == 0, 0.0, attn_mask)
            # テンソルattn_maskを変数として保存
            self.attn_mask = keras.Variable(
                initializer=attn_mask,
                shape=attn_mask.shape,
                dtype=attn_mask.dtype,
                trainable=False,
            )

    def call(self, x, training=False):
        """フォワードパスを設定

        Args:
            x: 位置情報埋め込み後の特徴マップ(bs, 256, 64)
            training(bool): トレーニングモードかどうか
        Returns:
            x: SwinTransformerブロックの出力(bs, 256(パッチ数), 64)
        """
        # num_patch(高さ=16, 幅=16))からパッチの高さ方向の数と幅方向の数を取得
        height, width = self.num_patch
        # 入力の特徴マップからパッチの数とチャンネルの次元数を取得
        _, num_patches_before, channels = x.shape
        # スキップ接続(残差接続)のために入力を保存
        x_skip = x
        # 入力を正規化
        x = self.norm1(x)
        # 特徴マップを再整形
        # (bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64)
        x = ops.reshape(x, (-1, height, width, channels))

        # シフト処理
        # shifted_xの形状: (bs, 16, 16, 64)
        if self.shift_size > 0:
            # シフトサイズが0より大きい場合、特徴マップの第2次元(高さ方向パッチ数)
            # と第3次元(幅方向パッチ数)をshift_sizeに従ってシフトする
            shifted_x = ops.roll(
                x,
                shift=[-self.shift_size, -self.shift_size],
                axis=[1, 2]
            )
        else:
             # シフトが0以下の場合は特徴マップをそのままshifted_xに代入
            shifted_x = x

        # shifted_xをウィンドウに分割
        # x_windowsの形状:(bs * 64(ウィンドウ数),
        #                  2(ウィンドウ内パッチ数(高さ)),
        #                  2(ウインドウ内パッチ数(幅)),
        #                  64)
        x_windows = window_partition(shifted_x, self.window_size)

        # ウィンドウ内パッチ数の次元をフラット化して再整形
        # x_windowsの形状:(bs * 64(ウィンドウ数), 4(ウィンドウ内パッチ数), 64)
        x_windows = ops.reshape(
            x_windows, (-1, self.window_size * self.window_size, channels)
        )

        # x_windowsをWindowAttentionブロックに入力
        # アテンションマスクself.attn_maskを適用してアテンションスコアを取得
        # attn_windowsの形状:(bs * 64, 4, 64)
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        # attn_windowsを再整形する
        # (bs * 64, 2(ウィンドウ高さ), 2(ウィンドウ幅), 64)
        attn_windows = ops.reshape(
            attn_windows,
            (-1, self.window_size, self.window_size, channels),
        )

        # attn_windowsをウィンドウ分割前の形状に戻し、shifted_xに代入
        # shifted_xの形状:(bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64)
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )

        # シフト処理を行った場合はもう一度シフト処理を行ってシフト前の状態に戻す
        # xの形状:(bs, 16(高さ方向パッチ数), 16(幅方向パッチ数), 64)
        if self.shift_size > 0:
            # シフトサイズが0より大きい場合、shifted_xの第2次元(高さ方向パッチ数)
            # と第3次元(幅方向パッチ数)をshift_sizeに従ってシフトする
            x = ops.roll(
                shifted_x,
                shift=[self.shift_size, self.shift_size],
                axis=[1, 2]
            )
        else:
            # シフトを行わなかった場合はshifted_xをそのままxに代入
            x = shifted_x

        # xの形状:(bs, 16(高さパッチ数), 16(幅パッチ数), 64)
        # 再整形: (bs, 256(パッチ数), 64)
        x = ops.reshape(x, (-1, height * width, channels))
        # ドロップアウトを適用
        x = self.drop_path(x, training=training)
        # スキップ接続を適用
        x = x_skip + x
        # スキップ接続のために入力を保存
        x_skip = x
        # 正規化を行う
        x = self.norm2(x)
        # MLPに入力
        # 最終の全結合層(ユニット数:64)なので、xの形状は変わらない
        x = self.mlp(x)
        # ドロップアウトを適用
        x = self.drop_path(x)
        # スキップ接続を適用
        x = x_skip + x

        # xの形状:(bs, 256(パッチ数), 64)
        return x

# %%
class PatchMerging(layers.Layer):
    """ layers.Layerを継承したカスタムレイヤー

    パッチを2x2のサイズにグループ化し、パッチグループ1個当たりの
    チャンネル次元数256(64 * 4)を線形変換で1/2の128にする

    Attributes:
        num_patch(tuple): パッチの数
        embed_dim(int): 埋め込み次元数
        linear_trans(layers.Dense):
            統合されたパッチのチャンネル次元を線形変換する全結合層
    """
    def __init__(self, num_patch, embed_dim):
        """
        Args:
            num_patch(tuple): 1画像当たりのパッチ数(高さ=16, 幅=16))
            embed_dim(int): 埋め込み次元数(embed_dim = 64)
        """
        super().__init__()
        # パッチの数(16, 16)を設定
        self.num_patch = num_patch
        # 埋め込み次元数を設定
        self.embed_dim = embed_dim
        # 統合されたパッチのチャンネル次元を線形変換する全結合層
        # ユニット数: 128(バイアス無し)
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        """ フォワードパス
        Args:
            x: SwinTransformerブロックから出力されたテンソル
               (bs, 256, 64)
        Returns:
            x: Patch Merging処理後のテンソル
               (bs, 64, 128)
        """
        # パッチの高さ方向の数(16)と幅方向の数(16)を取得
        height, width = self.num_patch
        # 入力テンソルのチャンネル次元数(64)を取得
        _, _, C = x.shape
        # 入力テンソルを再整形; (bs, 16, 16, 64)
        x = ops.reshape(x, (-1, height, width, C))

        # パッチを2x2の単位でまとめる(グループ化する)ための準備
        x0 = x[:, 0::2, 0::2, :]  # 偶数行・偶数列のパッチを取得:(bs, 8, 8, 64)
        x1 = x[:, 1::2, 0::2, :]  # 奇数行・偶数列のパッチを取得:(bs, 8, 8, 64)
        x2 = x[:, 0::2, 1::2, :]  # 偶数行・奇数列のパッチを取得:(bs, 8, 8, 64)
        x3 = x[:, 1::2, 1::2, :]  # 奇数行・奇数列のパッチを取得:(bs, 8, 8, 64)

        # 取得したパッチを上下左右2x2の単位でグループを作る
        # 64のパッチグループになる(縦方向8, 幅方向8)
        # xの形状: (bs, 8, 8, 256(チャンネル次元数64 * 4))
        x = ops.concatenate((x0, x1, x2, x3), axis=-1)
        # グループ化された8x8のパッチを64(パッチグループ数)に再整形
        # (bs, 64(当初のパッチ数の1/4), 256(チャンネル次元数64 * 4))
        x = ops.reshape(x, (-1, (height // 2) * (width // 2), 4 * C))
        # 64のパッチグループそれぞれのチャンネル次元数256を全結合層で128にする
        # 線形変換後のテンソル(bs, 64, 128)を返す
        return self.linear_trans(x)

# %%
def augment(x):
    """ 入力画像に対してデータ拡張を行う

    Args:
        x: 入力画像テンソル。(32, 32, 3)
    Returns:
        x: 拡張処理後の画像テンソル。(32, 32, 3)
    """
    # ランダムクロップを適用
    x = tf.image.random_crop(x, size=(image_dimension, image_dimension, 3))
    # 左右反転を適用
    x = tf.image.random_flip_left_right(x)
    # ランダムズームを適用
    scales = tf.random.uniform(shape=[], minval=0.8, maxval=1.2)
    new_height = tf.cast(image_dimension * scales, tf.int32)
    new_width = tf.cast(image_dimension * scales, tf.int32)
    x = tf.image.resize(x, [new_height, new_width])
    x = tf.image.resize_with_crop_or_pad(x, image_dimension, image_dimension)
    # ランダムコントラストを適用
    x = tf.image.random_contrast(x, 0.8, 1.2)
    # ランダム輝度を適用
    x = tf.image.random_brightness(x, 0.2)

    return x

""" トレーニングデータセット

"""
dataset = (
    # トレーニングデータセットを入力テンソルx_trainとy_trainのスライスから作成
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    # augment()関数を適用して画像データを拡張処理
    .map(lambda x, y: (augment(x), y))
    # トレーニングデータをバッチ単位(batch_size=128)に分ける: (bs, 32, 32, 3)
    .batch(batch_size=batch_size)
    # 画像データにpatch_extract()関数を適用してパッチに分割: (bs, 256, 12)
    .map(lambda x, y: (patch_extract(x), y))
    # データの読み込みと前処理が非同期で行われるようにする
    .prefetch(tf.data.experimental.AUTOTUNE)
)

""" 検証データセット
    検証データセットにはデータ拡張を行わない
"""
dataset_val = (
    # 検証データセットを入力テンソルx_valとy_valのスライスから作成
    tf.data.Dataset.from_tensor_slices((x_val, y_val))
    # 検証データをバッチ単位(batch_size=128)に分ける: (bs, 32, 32, 3)
    .batch(batch_size=batch_size)
    # 画像データにpatch_extract()関数を適用してパッチに分割: (bs, 256, 12)
    .map(lambda x, y: (patch_extract(x), y))
    .prefetch(tf.data.experimental.AUTOTUNE) # 非同期処理の設定
)


""" テストデータセット
    テストデータセットにはデータ拡張を行わない
"""
dataset_test = (
    # テストデータセットを入力テンソルx_testとy_testのスライスから作成
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    # テストデータをバッチ単位(batch_size=128)に分ける: (bs, 32, 32, 3)
    .batch(batch_size=batch_size)
    # 画像データにpatch_extract()関数を適用してパッチに分割: (bs, 256, 12)
    .map(lambda x, y: (patch_extract(x), y))
    .prefetch(tf.data.experimental.AUTOTUNE) # 非同期処理の設定
)

# %%
from tensorflow.keras import callbacks

# 学習率スケジューラーの定義
def scheduler(epoch, lr):
    if epoch < 50:
        return lr
    elif epoch < 100:
        return float(lr * tf.math.exp(-0.1))
    else:
        return float(lr * tf.math.exp(-0.2))

lr_scheduler = callbacks.LearningRateScheduler(scheduler)

""" SwinTransformerモデルの各ブロック(レイヤー)への順伝搬処理を定義

"""
# 入力レイヤー: モデルに入力されるのはパッチ分割後の画像テンソル
# 1画像当たり(256, 12)
input = layers.Input(shape=(256, 12))

# PatchEmbedding: パッチに分割後のテンソル(256, 12)に位置情報を埋め込む
# 位置情報埋め込み後の特徴マップの形状: (bs, 256, 64)
# num_patch_x = input_shape[0] // patch_size[0] # パッチ数(高さ方向)(16)
# num_patch_y = input_shape[1] // patch_size[1] # パッチ数(幅方向)(16)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(input)

# SwinTransformerブロック1:
# ここではシフトサイズが0なので、ウィンドウのシフトは行われない
# 出力xの形状: (bs, 256, 64)
x = SwinTransformer(
    dim=embed_dim, # 位置情報の次元数(embed_dim = 64)
    num_patch=(num_patch_x, num_patch_y), # パッチ数(高さ=16, 幅=16)
    num_heads=num_heads,  # ヘッドの数(num_heads = 8)
    window_size=window_size, # ウィンドウのサイズ(window_size = 2)
    shift_size=0, # シフトサイズ(シフトなし)
    num_mlp=num_mlp, # 全結合層のユニット数(num_mlp = 256)
    qkv_bias=qkv_bias,  # q、k、vにバイアスを追加する(qkv_bias = True)
    dropout_rate=dropout_rate,  # ドロップアウト率(dropout_rate = 0.1)
)(x)

# SwinTransformerブロック2:
# ここではシフトサイズが設定されているので、ウィンドウのシフトが行われる
# 出力xの形状: (bs, 256, 64)
x = SwinTransformer(  # もう一つのSwin Transformerブロックを適用
    dim=embed_dim,  # 位置情報の次元数(embed_dim = 64)
    num_patch=(num_patch_x, num_patch_y), # パッチ数(高さ=16, 幅=16)
    num_heads=num_heads,  # ヘッドの数(num_heads = 8)
    window_size=window_size,  # ウィンドウのサイズ(window_size = 2)
    shift_size=shift_size,  # シフトサイズ(shift_size = 1)を設定
    num_mlp=num_mlp, # 全結合層のユニット数(num_mlp = 256)
    qkv_bias=qkv_bias,  # q、k、vにバイアスを追加する(qkv_bias = True)
    dropout_rate=dropout_rate,  # ドロップアウト率(dropout_rate = 0.1)
)(x)

# SwinTransformerブロック3:
# ここではシフトサイズが設定されているので、ウィンドウのシフトが行われる
# 出力xの形状: (bs, 256, 64)
x = SwinTransformer(  # もう一つのSwin Transformerブロックを適用
    dim=embed_dim,  # 位置情報の次元数(embed_dim = 64)
    num_patch=(num_patch_x, num_patch_y), # パッチ数(高さ=16, 幅=16)
    num_heads=num_heads,  # ヘッドの数(num_heads = 8)
    window_size=window_size,  # ウィンドウのサイズ(window_size = 2)
    shift_size=shift_size,  # シフトサイズ(shift_size = 1)を設定
    num_mlp=num_mlp, # 全結合層のユニット数(num_mlp = 256)
    qkv_bias=qkv_bias,  # q、k、vにバイアスを追加する(qkv_bias = True)
    dropout_rate=dropout_rate,  # ドロップアウト率(dropout_rate = 0.1)
)(x)

# Patch Merging
# 複数のパッチを統合し、解像度を下げる(チャンネル次元数を減らす)
# 出力xの形状:(bs, 64, 128)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)

# グローバル平均プーリング:
# 統合したパッチグループの全てのチャンネル次元を平均化し、チャンネル次元だけにする
# 出力xの形状:(bs, 128)
x = layers.GlobalAveragePooling1D()(x)

# 出力層:
# ユニット数100の全結合層を定義し、ソフトマックス関数を適用して各クラスの確率を出力
# outputの形状: (bs, 100)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
# %%time
# モデルを作成、コンパイルする
model = keras.Model(input, output)
model.compile(
    # 損失関数としてカテゴリカルクロスエントロピーを設定
    loss=keras.losses.CategoricalCrossentropy(
        # ラベル平滑化の係数を設定(label_smoothing = 0.1)
        label_smoothing=label_smoothing
    ),
    # オプティマイザー(最適化器)にAdamWを使用
    optimizer=keras.optimizers.AdamW(
        # learning_rate = 1e-3  # 学習率
        learning_rate=learning_rate,
        # 重み減衰の割合(weight_decay = 0.0001)
        weight_decay=weight_decay
    ),
    # モデルの評価指標として正解率、トップ5の正解率を設定
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)
# モデルのサマリを出力
model.summary()

# トレーニング開始
history = model.fit(
    dataset,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_data=dataset_val,
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 256, 12)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ patch_embedding (PatchEmbedding)     │ (None, 256, 256)            │          68,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ swin_transformer (SwinTransformer)   │ (None, 256, 256)            │         789,848 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ swin_transformer_1 (SwinTransformer) │ (None, 256, 256)            │         790,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ swin_transformer_2 (SwinTransformer) │ (None, 256, 256)            │         790,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ patch_merging (PatchMerging)         │ (None, 64, 512)             │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 100)                 │          51,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,016,044 (11.51 MB)
#  Trainable params: 3,013,948 (11.50 MB)
#  Non-trainable params: 2,096 (16.38 KB)
# Epoch 1/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 93s 80ms/step - accuracy: 0.0411 - loss: 5.5126 - top-5-accuracy: 0.1506 - val_accuracy: 0.1034 - val_loss: 4.1812 - val_top-5-accuracy: 0.3230
# Epoch 2/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.1248 - loss: 3.9326 - top-5-accuracy: 0.3535 - val_accuracy: 0.1668 - val_loss: 3.8850 - val_top-5-accuracy: 0.4182
# Epoch 3/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.1675 - loss: 3.7227 - top-5-accuracy: 0.4272 - val_accuracy: 0.2182 - val_loss: 3.5821 - val_top-5-accuracy: 0.5034
# Epoch 4/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.1959 - loss: 3.6071 - top-5-accuracy: 0.4708 - val_accuracy: 0.2358 - val_loss: 3.5446 - val_top-5-accuracy: 0.5192
# Epoch 5/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2179 - loss: 3.5085 - top-5-accuracy: 0.5025 - val_accuracy: 0.2504 - val_loss: 3.4061 - val_top-5-accuracy: 0.5518
# Epoch 6/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2335 - loss: 3.4453 - top-5-accuracy: 0.5259 - val_accuracy: 0.2752 - val_loss: 3.3517 - val_top-5-accuracy: 0.5750
# Epoch 7/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2478 - loss: 3.3832 - top-5-accuracy: 0.5436 - val_accuracy: 0.2784 - val_loss: 3.3020 - val_top-5-accuracy: 0.5854
# Epoch 8/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2600 - loss: 3.3303 - top-5-accuracy: 0.5582 - val_accuracy: 0.3020 - val_loss: 3.3126 - val_top-5-accuracy: 0.5864
# Epoch 9/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2767 - loss: 3.2758 - top-5-accuracy: 0.5752 - val_accuracy: 0.3154 - val_loss: 3.2479 - val_top-5-accuracy: 0.6224
# Epoch 10/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.2888 - loss: 3.2103 - top-5-accuracy: 0.5958 - val_accuracy: 0.3234 - val_loss: 3.1817 - val_top-5-accuracy: 0.6342
# Epoch 11/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3039 - loss: 3.1598 - top-5-accuracy: 0.6135 - val_accuracy: 0.3372 - val_loss: 3.1370 - val_top-5-accuracy: 0.6532
# Epoch 12/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3162 - loss: 3.1103 - top-5-accuracy: 0.6203 - val_accuracy: 0.3372 - val_loss: 3.1591 - val_top-5-accuracy: 0.6556
# Epoch 13/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3314 - loss: 3.0607 - top-5-accuracy: 0.6349 - val_accuracy: 0.3612 - val_loss: 3.0658 - val_top-5-accuracy: 0.6732
# Epoch 14/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3419 - loss: 3.0128 - top-5-accuracy: 0.6518 - val_accuracy: 0.3514 - val_loss: 3.1016 - val_top-5-accuracy: 0.6704
# Epoch 15/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3538 - loss: 2.9636 - top-5-accuracy: 0.6631 - val_accuracy: 0.3660 - val_loss: 3.0429 - val_top-5-accuracy: 0.6756
# Epoch 16/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3649 - loss: 2.9175 - top-5-accuracy: 0.6776 - val_accuracy: 0.3896 - val_loss: 2.9531 - val_top-5-accuracy: 0.7066
# Epoch 17/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3759 - loss: 2.8758 - top-5-accuracy: 0.6885 - val_accuracy: 0.3978 - val_loss: 2.9660 - val_top-5-accuracy: 0.6982
# Epoch 18/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3878 - loss: 2.8382 - top-5-accuracy: 0.6983 - val_accuracy: 0.3764 - val_loss: 3.0169 - val_top-5-accuracy: 0.7012
# Epoch 19/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.3904 - loss: 2.8173 - top-5-accuracy: 0.7046 - val_accuracy: 0.3962 - val_loss: 2.9326 - val_top-5-accuracy: 0.7098
# Epoch 20/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4001 - loss: 2.7812 - top-5-accuracy: 0.7150 - val_accuracy: 0.3996 - val_loss: 2.9903 - val_top-5-accuracy: 0.7120
# Epoch 21/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4100 - loss: 2.7472 - top-5-accuracy: 0.7220 - val_accuracy: 0.4094 - val_loss: 2.9343 - val_top-5-accuracy: 0.7148
# Epoch 22/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4226 - loss: 2.7176 - top-5-accuracy: 0.7283 - val_accuracy: 0.4082 - val_loss: 2.9287 - val_top-5-accuracy: 0.7194
# Epoch 23/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4274 - loss: 2.6952 - top-5-accuracy: 0.7342 - val_accuracy: 0.4194 - val_loss: 2.9001 - val_top-5-accuracy: 0.7222
# Epoch 24/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4378 - loss: 2.6678 - top-5-accuracy: 0.7407 - val_accuracy: 0.4256 - val_loss: 2.9164 - val_top-5-accuracy: 0.7316
# Epoch 25/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4408 - loss: 2.6479 - top-5-accuracy: 0.7497 - val_accuracy: 0.4226 - val_loss: 2.9281 - val_top-5-accuracy: 0.7290
# Epoch 26/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4482 - loss: 2.6271 - top-5-accuracy: 0.7541 - val_accuracy: 0.4392 - val_loss: 2.8893 - val_top-5-accuracy: 0.7418
# Epoch 27/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4502 - loss: 2.6060 - top-5-accuracy: 0.7585 - val_accuracy: 0.4324 - val_loss: 2.9091 - val_top-5-accuracy: 0.7254
# Epoch 28/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4568 - loss: 2.5843 - top-5-accuracy: 0.7637 - val_accuracy: 0.4440 - val_loss: 2.8904 - val_top-5-accuracy: 0.7402
# Epoch 29/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4634 - loss: 2.5719 - top-5-accuracy: 0.7660 - val_accuracy: 0.4484 - val_loss: 2.8591 - val_top-5-accuracy: 0.7464
# Epoch 30/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4699 - loss: 2.5472 - top-5-accuracy: 0.7734 - val_accuracy: 0.4296 - val_loss: 2.9357 - val_top-5-accuracy: 0.7376
# Epoch 31/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4808 - loss: 2.5148 - top-5-accuracy: 0.7832 - val_accuracy: 0.4380 - val_loss: 2.9778 - val_top-5-accuracy: 0.7316
# Epoch 32/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4779 - loss: 2.5171 - top-5-accuracy: 0.7765 - val_accuracy: 0.4496 - val_loss: 2.8869 - val_top-5-accuracy: 0.7446
# Epoch 33/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4860 - loss: 2.4934 - top-5-accuracy: 0.7846 - val_accuracy: 0.4516 - val_loss: 2.8391 - val_top-5-accuracy: 0.7552
# Epoch 34/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4876 - loss: 2.4827 - top-5-accuracy: 0.7891 - val_accuracy: 0.4610 - val_loss: 2.8360 - val_top-5-accuracy: 0.7536
# Epoch 35/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4938 - loss: 2.4563 - top-5-accuracy: 0.7940 - val_accuracy: 0.4690 - val_loss: 2.8829 - val_top-5-accuracy: 0.7462
# Epoch 36/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.4973 - loss: 2.4472 - top-5-accuracy: 0.7967 - val_accuracy: 0.4600 - val_loss: 2.8245 - val_top-5-accuracy: 0.7498
# Epoch 37/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5022 - loss: 2.4297 - top-5-accuracy: 0.8003 - val_accuracy: 0.4704 - val_loss: 2.7878 - val_top-5-accuracy: 0.7570
# Epoch 38/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5075 - loss: 2.4239 - top-5-accuracy: 0.8041 - val_accuracy: 0.4748 - val_loss: 2.8237 - val_top-5-accuracy: 0.7660
# Epoch 39/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5130 - loss: 2.3998 - top-5-accuracy: 0.8086 - val_accuracy: 0.4572 - val_loss: 2.8371 - val_top-5-accuracy: 0.7474
# Epoch 40/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5183 - loss: 2.3834 - top-5-accuracy: 0.8089 - val_accuracy: 0.4596 - val_loss: 2.8574 - val_top-5-accuracy: 0.7562
# Epoch 41/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5222 - loss: 2.3655 - top-5-accuracy: 0.8151 - val_accuracy: 0.4664 - val_loss: 2.8357 - val_top-5-accuracy: 0.7640
# Epoch 42/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5257 - loss: 2.3598 - top-5-accuracy: 0.8173 - val_accuracy: 0.4720 - val_loss: 2.8237 - val_top-5-accuracy: 0.7628
# Epoch 43/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5282 - loss: 2.3485 - top-5-accuracy: 0.8185 - val_accuracy: 0.4606 - val_loss: 2.8773 - val_top-5-accuracy: 0.7522
# Epoch 44/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5325 - loss: 2.3364 - top-5-accuracy: 0.8222 - val_accuracy: 0.4650 - val_loss: 2.8645 - val_top-5-accuracy: 0.7498
# Epoch 45/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5350 - loss: 2.3213 - top-5-accuracy: 0.8259 - val_accuracy: 0.4792 - val_loss: 2.8213 - val_top-5-accuracy: 0.7668
# Epoch 46/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5424 - loss: 2.3078 - top-5-accuracy: 0.8269 - val_accuracy: 0.4738 - val_loss: 2.8672 - val_top-5-accuracy: 0.7596
# Epoch 47/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5442 - loss: 2.2967 - top-5-accuracy: 0.8312 - val_accuracy: 0.4622 - val_loss: 2.9263 - val_top-5-accuracy: 0.7570
# Epoch 48/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5474 - loss: 2.2872 - top-5-accuracy: 0.8346 - val_accuracy: 0.4756 - val_loss: 2.8998 - val_top-5-accuracy: 0.7540
# Epoch 49/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5515 - loss: 2.2727 - top-5-accuracy: 0.8372 - val_accuracy: 0.4786 - val_loss: 2.8304 - val_top-5-accuracy: 0.7614
# Epoch 50/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5592 - loss: 2.2554 - top-5-accuracy: 0.8398 - val_accuracy: 0.4888 - val_loss: 2.8462 - val_top-5-accuracy: 0.7610
# Epoch 51/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5603 - loss: 2.2482 - top-5-accuracy: 0.8430 - val_accuracy: 0.4748 - val_loss: 2.8792 - val_top-5-accuracy: 0.7544
# Epoch 52/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5625 - loss: 2.2364 - top-5-accuracy: 0.8453 - val_accuracy: 0.4832 - val_loss: 2.7912 - val_top-5-accuracy: 0.7642
# Epoch 53/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5675 - loss: 2.2234 - top-5-accuracy: 0.8469 - val_accuracy: 0.4690 - val_loss: 2.8831 - val_top-5-accuracy: 0.7596
# Epoch 54/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5687 - loss: 2.2143 - top-5-accuracy: 0.8511 - val_accuracy: 0.4828 - val_loss: 2.8682 - val_top-5-accuracy: 0.7574
# Epoch 55/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5656 - loss: 2.2167 - top-5-accuracy: 0.8507 - val_accuracy: 0.4708 - val_loss: 2.8578 - val_top-5-accuracy: 0.7630
# Epoch 56/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5748 - loss: 2.1957 - top-5-accuracy: 0.8530 - val_accuracy: 0.4822 - val_loss: 2.8568 - val_top-5-accuracy: 0.7656
# Epoch 57/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.5788 - loss: 2.1853 - top-5-accuracy: 0.8557 - val_accuracy: 0.4866 - val_loss: 2.8707 - val_top-5-accuracy: 0.7700
# Epoch 58/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5870 - loss: 2.1716 - top-5-accuracy: 0.8598 - val_accuracy: 0.4804 - val_loss: 2.8324 - val_top-5-accuracy: 0.7638
# Epoch 59/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5901 - loss: 2.1641 - top-5-accuracy: 0.8564 - val_accuracy: 0.4794 - val_loss: 2.9010 - val_top-5-accuracy: 0.7610
# Epoch 60/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5903 - loss: 2.1550 - top-5-accuracy: 0.8635 - val_accuracy: 0.4768 - val_loss: 2.9039 - val_top-5-accuracy: 0.7614
# Epoch 61/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5921 - loss: 2.1496 - top-5-accuracy: 0.8644 - val_accuracy: 0.4846 - val_loss: 2.8442 - val_top-5-accuracy: 0.7654
# Epoch 62/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5962 - loss: 2.1343 - top-5-accuracy: 0.8680 - val_accuracy: 0.4674 - val_loss: 2.9396 - val_top-5-accuracy: 0.7580
# Epoch 63/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5972 - loss: 2.1294 - top-5-accuracy: 0.8701 - val_accuracy: 0.4680 - val_loss: 2.9307 - val_top-5-accuracy: 0.7490
# Epoch 64/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.5972 - loss: 2.1220 - top-5-accuracy: 0.8720 - val_accuracy: 0.4836 - val_loss: 2.8837 - val_top-5-accuracy: 0.7606
# Epoch 65/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6048 - loss: 2.1105 - top-5-accuracy: 0.8744 - val_accuracy: 0.4806 - val_loss: 2.8716 - val_top-5-accuracy: 0.7622
# Epoch 66/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6042 - loss: 2.1034 - top-5-accuracy: 0.8771 - val_accuracy: 0.4820 - val_loss: 2.9199 - val_top-5-accuracy: 0.7604
# Epoch 67/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6074 - loss: 2.0937 - top-5-accuracy: 0.8773 - val_accuracy: 0.4794 - val_loss: 2.9177 - val_top-5-accuracy: 0.7620
# Epoch 68/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6080 - loss: 2.0873 - top-5-accuracy: 0.8799 - val_accuracy: 0.4712 - val_loss: 2.9595 - val_top-5-accuracy: 0.7548
# Epoch 69/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6123 - loss: 2.0869 - top-5-accuracy: 0.8778 - val_accuracy: 0.4782 - val_loss: 2.9222 - val_top-5-accuracy: 0.7606
# Epoch 70/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6168 - loss: 2.0682 - top-5-accuracy: 0.8823 - val_accuracy: 0.4832 - val_loss: 2.8845 - val_top-5-accuracy: 0.7602
# Epoch 71/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6169 - loss: 2.0664 - top-5-accuracy: 0.8830 - val_accuracy: 0.4862 - val_loss: 2.8941 - val_top-5-accuracy: 0.7576
# Epoch 72/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6203 - loss: 2.0503 - top-5-accuracy: 0.8875 - val_accuracy: 0.4846 - val_loss: 2.9144 - val_top-5-accuracy: 0.7656
# Epoch 73/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6197 - loss: 2.0489 - top-5-accuracy: 0.8855 - val_accuracy: 0.4722 - val_loss: 2.9279 - val_top-5-accuracy: 0.7634
# Epoch 74/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6266 - loss: 2.0367 - top-5-accuracy: 0.8888 - val_accuracy: 0.4774 - val_loss: 2.8752 - val_top-5-accuracy: 0.7588
# Epoch 75/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6309 - loss: 2.0269 - top-5-accuracy: 0.8931 - val_accuracy: 0.4884 - val_loss: 2.8742 - val_top-5-accuracy: 0.7660
# Epoch 76/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6342 - loss: 2.0167 - top-5-accuracy: 0.8928 - val_accuracy: 0.4814 - val_loss: 2.9470 - val_top-5-accuracy: 0.7568
# Epoch 77/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6398 - loss: 2.0150 - top-5-accuracy: 0.8927 - val_accuracy: 0.4822 - val_loss: 2.9193 - val_top-5-accuracy: 0.7626
# Epoch 78/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6378 - loss: 2.0096 - top-5-accuracy: 0.8956 - val_accuracy: 0.4708 - val_loss: 2.9469 - val_top-5-accuracy: 0.7486
# Epoch 79/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6356 - loss: 2.0069 - top-5-accuracy: 0.8959 - val_accuracy: 0.4756 - val_loss: 2.9509 - val_top-5-accuracy: 0.7530
# Epoch 80/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6394 - loss: 1.9944 - top-5-accuracy: 0.8966 - val_accuracy: 0.4764 - val_loss: 2.9554 - val_top-5-accuracy: 0.7548
# Epoch 81/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6439 - loss: 1.9877 - top-5-accuracy: 0.8999 - val_accuracy: 0.4786 - val_loss: 2.9861 - val_top-5-accuracy: 0.7578
# Epoch 82/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6440 - loss: 1.9788 - top-5-accuracy: 0.9021 - val_accuracy: 0.4746 - val_loss: 2.9370 - val_top-5-accuracy: 0.7532
# Epoch 83/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6432 - loss: 1.9773 - top-5-accuracy: 0.8993 - val_accuracy: 0.4756 - val_loss: 2.9813 - val_top-5-accuracy: 0.7548
# Epoch 84/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6469 - loss: 1.9721 - top-5-accuracy: 0.9010 - val_accuracy: 0.4716 - val_loss: 3.0159 - val_top-5-accuracy: 0.7530
# Epoch 85/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6580 - loss: 1.9449 - top-5-accuracy: 0.9070 - val_accuracy: 0.4680 - val_loss: 3.0141 - val_top-5-accuracy: 0.7494
# Epoch 86/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6559 - loss: 1.9548 - top-5-accuracy: 0.9065 - val_accuracy: 0.4696 - val_loss: 3.0634 - val_top-5-accuracy: 0.7522
# Epoch 87/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6560 - loss: 1.9539 - top-5-accuracy: 0.9061 - val_accuracy: 0.4776 - val_loss: 2.9654 - val_top-5-accuracy: 0.7538
# Epoch 88/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6614 - loss: 1.9348 - top-5-accuracy: 0.9091 - val_accuracy: 0.4686 - val_loss: 3.0715 - val_top-5-accuracy: 0.7424
# Epoch 89/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6577 - loss: 1.9420 - top-5-accuracy: 0.9097 - val_accuracy: 0.4668 - val_loss: 3.0915 - val_top-5-accuracy: 0.7410
# Epoch 90/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6577 - loss: 1.9348 - top-5-accuracy: 0.9130 - val_accuracy: 0.4666 - val_loss: 3.0715 - val_top-5-accuracy: 0.7404
# Epoch 91/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6595 - loss: 1.9289 - top-5-accuracy: 0.9116 - val_accuracy: 0.4754 - val_loss: 3.1000 - val_top-5-accuracy: 0.7464
# Epoch 92/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6635 - loss: 1.9248 - top-5-accuracy: 0.9130 - val_accuracy: 0.4732 - val_loss: 3.1051 - val_top-5-accuracy: 0.7532
# Epoch 93/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6717 - loss: 1.9141 - top-5-accuracy: 0.9139 - val_accuracy: 0.4712 - val_loss: 3.0853 - val_top-5-accuracy: 0.7430
# Epoch 94/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6731 - loss: 1.9040 - top-5-accuracy: 0.9172 - val_accuracy: 0.4670 - val_loss: 3.1763 - val_top-5-accuracy: 0.7364
# Epoch 95/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6756 - loss: 1.8974 - top-5-accuracy: 0.9177 - val_accuracy: 0.4716 - val_loss: 3.1590 - val_top-5-accuracy: 0.7430
# Epoch 96/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6740 - loss: 1.8940 - top-5-accuracy: 0.9185 - val_accuracy: 0.4658 - val_loss: 3.1802 - val_top-5-accuracy: 0.7368
# Epoch 97/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6776 - loss: 1.8906 - top-5-accuracy: 0.9191 - val_accuracy: 0.4690 - val_loss: 3.1631 - val_top-5-accuracy: 0.7380
# Epoch 98/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6793 - loss: 1.8793 - top-5-accuracy: 0.9215 - val_accuracy: 0.4714 - val_loss: 3.1531 - val_top-5-accuracy: 0.7422
# Epoch 99/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6793 - loss: 1.8826 - top-5-accuracy: 0.9224 - val_accuracy: 0.4634 - val_loss: 3.1263 - val_top-5-accuracy: 0.7334
# Epoch 100/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6844 - loss: 1.8701 - top-5-accuracy: 0.9223 - val_accuracy: 0.4668 - val_loss: 3.1817 - val_top-5-accuracy: 0.7348
# Epoch 101/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6835 - loss: 1.8753 - top-5-accuracy: 0.9217 - val_accuracy: 0.4732 - val_loss: 3.1837 - val_top-5-accuracy: 0.7328
# Epoch 102/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6887 - loss: 1.8637 - top-5-accuracy: 0.9239 - val_accuracy: 0.4732 - val_loss: 3.0847 - val_top-5-accuracy: 0.7396
# Epoch 103/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6891 - loss: 1.8474 - top-5-accuracy: 0.9261 - val_accuracy: 0.4562 - val_loss: 3.2160 - val_top-5-accuracy: 0.7302
# Epoch 104/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6912 - loss: 1.8595 - top-5-accuracy: 0.9243 - val_accuracy: 0.4548 - val_loss: 3.2181 - val_top-5-accuracy: 0.7318
# Epoch 105/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6891 - loss: 1.8501 - top-5-accuracy: 0.9298 - val_accuracy: 0.4730 - val_loss: 3.0794 - val_top-5-accuracy: 0.7442
# Epoch 106/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6945 - loss: 1.8453 - top-5-accuracy: 0.9285 - val_accuracy: 0.4674 - val_loss: 3.1238 - val_top-5-accuracy: 0.7388
# Epoch 107/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6961 - loss: 1.8328 - top-5-accuracy: 0.9293 - val_accuracy: 0.4540 - val_loss: 3.2829 - val_top-5-accuracy: 0.7202
# Epoch 108/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6932 - loss: 1.8347 - top-5-accuracy: 0.9316 - val_accuracy: 0.4570 - val_loss: 3.2516 - val_top-5-accuracy: 0.7298
# Epoch 109/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7001 - loss: 1.8188 - top-5-accuracy: 0.9312 - val_accuracy: 0.4606 - val_loss: 3.1835 - val_top-5-accuracy: 0.7386
# Epoch 110/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.6974 - loss: 1.8285 - top-5-accuracy: 0.9311 - val_accuracy: 0.4658 - val_loss: 3.1569 - val_top-5-accuracy: 0.7342
# Epoch 111/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7045 - loss: 1.8134 - top-5-accuracy: 0.9318 - val_accuracy: 0.4622 - val_loss: 3.2209 - val_top-5-accuracy: 0.7408
# Epoch 112/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7046 - loss: 1.8125 - top-5-accuracy: 0.9334 - val_accuracy: 0.4658 - val_loss: 3.2264 - val_top-5-accuracy: 0.7412
# Epoch 113/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7074 - loss: 1.8062 - top-5-accuracy: 0.9341 - val_accuracy: 0.4760 - val_loss: 3.1988 - val_top-5-accuracy: 0.7404
# Epoch 114/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7096 - loss: 1.8000 - top-5-accuracy: 0.9351 - val_accuracy: 0.4830 - val_loss: 3.1271 - val_top-5-accuracy: 0.7500
# Epoch 115/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7091 - loss: 1.7965 - top-5-accuracy: 0.9373 - val_accuracy: 0.4704 - val_loss: 3.2691 - val_top-5-accuracy: 0.7332
# Epoch 116/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7083 - loss: 1.8023 - top-5-accuracy: 0.9333 - val_accuracy: 0.4662 - val_loss: 3.2075 - val_top-5-accuracy: 0.7434
# Epoch 117/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7075 - loss: 1.7920 - top-5-accuracy: 0.9380 - val_accuracy: 0.4496 - val_loss: 3.2618 - val_top-5-accuracy: 0.7268
# Epoch 118/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7078 - loss: 1.8002 - top-5-accuracy: 0.9373 - val_accuracy: 0.4710 - val_loss: 3.2172 - val_top-5-accuracy: 0.7456
# Epoch 119/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7195 - loss: 1.7771 - top-5-accuracy: 0.9392 - val_accuracy: 0.4760 - val_loss: 3.1681 - val_top-5-accuracy: 0.7386
# Epoch 120/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7163 - loss: 1.7804 - top-5-accuracy: 0.9385 - val_accuracy: 0.4594 - val_loss: 3.3069 - val_top-5-accuracy: 0.7254
# Epoch 121/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7190 - loss: 1.7782 - top-5-accuracy: 0.9384 - val_accuracy: 0.4576 - val_loss: 3.2856 - val_top-5-accuracy: 0.7338
# Epoch 122/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7271 - loss: 1.7528 - top-5-accuracy: 0.9456 - val_accuracy: 0.4542 - val_loss: 3.3560 - val_top-5-accuracy: 0.7290
# Epoch 123/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7212 - loss: 1.7663 - top-5-accuracy: 0.9406 - val_accuracy: 0.4686 - val_loss: 3.2948 - val_top-5-accuracy: 0.7286
# Epoch 124/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7197 - loss: 1.7670 - top-5-accuracy: 0.9431 - val_accuracy: 0.4770 - val_loss: 3.2920 - val_top-5-accuracy: 0.7300
# Epoch 125/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7214 - loss: 1.7611 - top-5-accuracy: 0.9443 - val_accuracy: 0.4594 - val_loss: 3.2856 - val_top-5-accuracy: 0.7230
# Epoch 126/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7247 - loss: 1.7550 - top-5-accuracy: 0.9446 - val_accuracy: 0.4702 - val_loss: 3.2677 - val_top-5-accuracy: 0.7328
# Epoch 127/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7238 - loss: 1.7517 - top-5-accuracy: 0.9467 - val_accuracy: 0.4624 - val_loss: 3.3707 - val_top-5-accuracy: 0.7282
# Epoch 128/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7308 - loss: 1.7432 - top-5-accuracy: 0.9451 - val_accuracy: 0.4620 - val_loss: 3.2606 - val_top-5-accuracy: 0.7358
# Epoch 129/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7296 - loss: 1.7410 - top-5-accuracy: 0.9472 - val_accuracy: 0.4590 - val_loss: 3.3833 - val_top-5-accuracy: 0.7290
# Epoch 130/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7264 - loss: 1.7486 - top-5-accuracy: 0.9464 - val_accuracy: 0.4576 - val_loss: 3.3465 - val_top-5-accuracy: 0.7308
# Epoch 131/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7305 - loss: 1.7459 - top-5-accuracy: 0.9446 - val_accuracy: 0.4624 - val_loss: 3.3861 - val_top-5-accuracy: 0.7216
# Epoch 132/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7295 - loss: 1.7360 - top-5-accuracy: 0.9477 - val_accuracy: 0.4520 - val_loss: 3.4538 - val_top-5-accuracy: 0.7196
# Epoch 133/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7316 - loss: 1.7335 - top-5-accuracy: 0.9474 - val_accuracy: 0.4542 - val_loss: 3.4393 - val_top-5-accuracy: 0.7248
# Epoch 134/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7363 - loss: 1.7274 - top-5-accuracy: 0.9479 - val_accuracy: 0.4560 - val_loss: 3.4057 - val_top-5-accuracy: 0.7202
# Epoch 135/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7366 - loss: 1.7218 - top-5-accuracy: 0.9480 - val_accuracy: 0.4572 - val_loss: 3.3921 - val_top-5-accuracy: 0.7154
# Epoch 136/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7410 - loss: 1.7177 - top-5-accuracy: 0.9489 - val_accuracy: 0.4512 - val_loss: 3.4298 - val_top-5-accuracy: 0.7100
# Epoch 137/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7360 - loss: 1.7193 - top-5-accuracy: 0.9519 - val_accuracy: 0.4446 - val_loss: 3.4233 - val_top-5-accuracy: 0.7118
# Epoch 138/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7431 - loss: 1.7083 - top-5-accuracy: 0.9507 - val_accuracy: 0.4486 - val_loss: 3.3847 - val_top-5-accuracy: 0.7224
# Epoch 139/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7464 - loss: 1.7018 - top-5-accuracy: 0.9525 - val_accuracy: 0.4462 - val_loss: 3.5366 - val_top-5-accuracy: 0.7040
# Epoch 140/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.7433 - loss: 1.7105 - top-5-accuracy: 0.9537 - val_accuracy: 0.4550 - val_loss: 3.4239 - val_top-5-accuracy: 0.7092
# Epoch 141/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7444 - loss: 1.7011 - top-5-accuracy: 0.9536 - val_accuracy: 0.4512 - val_loss: 3.4010 - val_top-5-accuracy: 0.7178
# Epoch 142/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7477 - loss: 1.6921 - top-5-accuracy: 0.9562 - val_accuracy: 0.4474 - val_loss: 3.5269 - val_top-5-accuracy: 0.7102
# Epoch 143/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7462 - loss: 1.6947 - top-5-accuracy: 0.9538 - val_accuracy: 0.4532 - val_loss: 3.4008 - val_top-5-accuracy: 0.7176
# Epoch 144/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7500 - loss: 1.6867 - top-5-accuracy: 0.9566 - val_accuracy: 0.4508 - val_loss: 3.5083 - val_top-5-accuracy: 0.7150
# Epoch 145/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7518 - loss: 1.6825 - top-5-accuracy: 0.9576 - val_accuracy: 0.4372 - val_loss: 3.5917 - val_top-5-accuracy: 0.7044
# Epoch 146/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7497 - loss: 1.6901 - top-5-accuracy: 0.9562 - val_accuracy: 0.4408 - val_loss: 3.5796 - val_top-5-accuracy: 0.6972
# Epoch 147/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7531 - loss: 1.6808 - top-5-accuracy: 0.9559 - val_accuracy: 0.4324 - val_loss: 3.6989 - val_top-5-accuracy: 0.6932
# Epoch 148/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7512 - loss: 1.6830 - top-5-accuracy: 0.9563 - val_accuracy: 0.4262 - val_loss: 3.6703 - val_top-5-accuracy: 0.6872
# Epoch 149/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7567 - loss: 1.6714 - top-5-accuracy: 0.9586 - val_accuracy: 0.4380 - val_loss: 3.6358 - val_top-5-accuracy: 0.6962
# Epoch 150/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7591 - loss: 1.6664 - top-5-accuracy: 0.9575 - val_accuracy: 0.4222 - val_loss: 3.6786 - val_top-5-accuracy: 0.6898
# Epoch 151/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7611 - loss: 1.6645 - top-5-accuracy: 0.9576 - val_accuracy: 0.4324 - val_loss: 3.6686 - val_top-5-accuracy: 0.6968
# Epoch 152/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7604 - loss: 1.6646 - top-5-accuracy: 0.9590 - val_accuracy: 0.4394 - val_loss: 3.5652 - val_top-5-accuracy: 0.6998
# Epoch 153/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7597 - loss: 1.6658 - top-5-accuracy: 0.9579 - val_accuracy: 0.4232 - val_loss: 3.7453 - val_top-5-accuracy: 0.6824
# Epoch 154/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7607 - loss: 1.6613 - top-5-accuracy: 0.9604 - val_accuracy: 0.4292 - val_loss: 3.6325 - val_top-5-accuracy: 0.6916
# Epoch 155/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7658 - loss: 1.6513 - top-5-accuracy: 0.9585 - val_accuracy: 0.4280 - val_loss: 3.6249 - val_top-5-accuracy: 0.6888
# Epoch 156/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7641 - loss: 1.6511 - top-5-accuracy: 0.9608 - val_accuracy: 0.4434 - val_loss: 3.4694 - val_top-5-accuracy: 0.7048
# Epoch 157/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7648 - loss: 1.6516 - top-5-accuracy: 0.9593 - val_accuracy: 0.4178 - val_loss: 3.6652 - val_top-5-accuracy: 0.6918
# Epoch 158/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7718 - loss: 1.6401 - top-5-accuracy: 0.9621 - val_accuracy: 0.4424 - val_loss: 3.5408 - val_top-5-accuracy: 0.7078
# Epoch 159/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7653 - loss: 1.6400 - top-5-accuracy: 0.9640 - val_accuracy: 0.4232 - val_loss: 3.6358 - val_top-5-accuracy: 0.6958
# Epoch 160/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7592 - loss: 1.6572 - top-5-accuracy: 0.9604 - val_accuracy: 0.4228 - val_loss: 3.6955 - val_top-5-accuracy: 0.6902
# Epoch 161/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7681 - loss: 1.6329 - top-5-accuracy: 0.9651 - val_accuracy: 0.4362 - val_loss: 3.5736 - val_top-5-accuracy: 0.6984
# Epoch 162/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7689 - loss: 1.6336 - top-5-accuracy: 0.9635 - val_accuracy: 0.4212 - val_loss: 3.6354 - val_top-5-accuracy: 0.6888
# Epoch 163/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7633 - loss: 1.6493 - top-5-accuracy: 0.9604 - val_accuracy: 0.4190 - val_loss: 3.7643 - val_top-5-accuracy: 0.6826
# Epoch 164/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7707 - loss: 1.6318 - top-5-accuracy: 0.9641 - val_accuracy: 0.4206 - val_loss: 3.6728 - val_top-5-accuracy: 0.6924
# Epoch 165/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7721 - loss: 1.6281 - top-5-accuracy: 0.9650 - val_accuracy: 0.4260 - val_loss: 3.6744 - val_top-5-accuracy: 0.6834
# Epoch 166/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7706 - loss: 1.6257 - top-5-accuracy: 0.9646 - val_accuracy: 0.4264 - val_loss: 3.6827 - val_top-5-accuracy: 0.6868
# Epoch 167/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7768 - loss: 1.6187 - top-5-accuracy: 0.9667 - val_accuracy: 0.4196 - val_loss: 3.7148 - val_top-5-accuracy: 0.6790
# Epoch 168/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7744 - loss: 1.6303 - top-5-accuracy: 0.9652 - val_accuracy: 0.4242 - val_loss: 3.6968 - val_top-5-accuracy: 0.6912
# Epoch 169/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7786 - loss: 1.6175 - top-5-accuracy: 0.9644 - val_accuracy: 0.4320 - val_loss: 3.6340 - val_top-5-accuracy: 0.7022
# Epoch 170/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7814 - loss: 1.6086 - top-5-accuracy: 0.9660 - val_accuracy: 0.4174 - val_loss: 3.6193 - val_top-5-accuracy: 0.6840
# Epoch 171/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7746 - loss: 1.6141 - top-5-accuracy: 0.9662 - val_accuracy: 0.4158 - val_loss: 3.8172 - val_top-5-accuracy: 0.6794
# Epoch 172/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7817 - loss: 1.6086 - top-5-accuracy: 0.9680 - val_accuracy: 0.4134 - val_loss: 3.7400 - val_top-5-accuracy: 0.6828
# Epoch 173/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7813 - loss: 1.6050 - top-5-accuracy: 0.9673 - val_accuracy: 0.4150 - val_loss: 3.7770 - val_top-5-accuracy: 0.6892
# Epoch 174/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7841 - loss: 1.6006 - top-5-accuracy: 0.9685 - val_accuracy: 0.4048 - val_loss: 3.7971 - val_top-5-accuracy: 0.6780
# Epoch 175/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7862 - loss: 1.5977 - top-5-accuracy: 0.9687 - val_accuracy: 0.4186 - val_loss: 3.7325 - val_top-5-accuracy: 0.6838
# Epoch 176/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7858 - loss: 1.5970 - top-5-accuracy: 0.9708 - val_accuracy: 0.4172 - val_loss: 3.7394 - val_top-5-accuracy: 0.6842
# Epoch 177/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7873 - loss: 1.5964 - top-5-accuracy: 0.9693 - val_accuracy: 0.4030 - val_loss: 3.8689 - val_top-5-accuracy: 0.6746
# Epoch 178/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7802 - loss: 1.6072 - top-5-accuracy: 0.9670 - val_accuracy: 0.4224 - val_loss: 3.7451 - val_top-5-accuracy: 0.6880
# Epoch 179/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7864 - loss: 1.5977 - top-5-accuracy: 0.9675 - val_accuracy: 0.4026 - val_loss: 3.8129 - val_top-5-accuracy: 0.6764
# Epoch 180/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7849 - loss: 1.6025 - top-5-accuracy: 0.9685 - val_accuracy: 0.4050 - val_loss: 3.7854 - val_top-5-accuracy: 0.6748
# Epoch 181/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7922 - loss: 1.5814 - top-5-accuracy: 0.9703 - val_accuracy: 0.4134 - val_loss: 3.7642 - val_top-5-accuracy: 0.6852
# Epoch 182/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7876 - loss: 1.5854 - top-5-accuracy: 0.9706 - val_accuracy: 0.4078 - val_loss: 3.7842 - val_top-5-accuracy: 0.6780
# Epoch 183/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7917 - loss: 1.5851 - top-5-accuracy: 0.9700 - val_accuracy: 0.4020 - val_loss: 3.7762 - val_top-5-accuracy: 0.6748
# Epoch 184/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7870 - loss: 1.5935 - top-5-accuracy: 0.9685 - val_accuracy: 0.4002 - val_loss: 3.9318 - val_top-5-accuracy: 0.6652
# Epoch 185/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7947 - loss: 1.5736 - top-5-accuracy: 0.9721 - val_accuracy: 0.4226 - val_loss: 3.7526 - val_top-5-accuracy: 0.6876
# Epoch 186/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7930 - loss: 1.5793 - top-5-accuracy: 0.9708 - val_accuracy: 0.4100 - val_loss: 3.8516 - val_top-5-accuracy: 0.6710
# Epoch 187/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7940 - loss: 1.5772 - top-5-accuracy: 0.9699 - val_accuracy: 0.4214 - val_loss: 3.7320 - val_top-5-accuracy: 0.6906
# Epoch 188/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7986 - loss: 1.5641 - top-5-accuracy: 0.9712 - val_accuracy: 0.4120 - val_loss: 3.8153 - val_top-5-accuracy: 0.6798
# Epoch 189/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.7891 - loss: 1.5806 - top-5-accuracy: 0.9711 - val_accuracy: 0.4276 - val_loss: 3.6325 - val_top-5-accuracy: 0.6942
# Epoch 190/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7934 - loss: 1.5770 - top-5-accuracy: 0.9723 - val_accuracy: 0.4212 - val_loss: 3.6247 - val_top-5-accuracy: 0.6924
# Epoch 191/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7951 - loss: 1.5706 - top-5-accuracy: 0.9734 - val_accuracy: 0.4128 - val_loss: 3.7638 - val_top-5-accuracy: 0.6854
# Epoch 192/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.7963 - loss: 1.5704 - top-5-accuracy: 0.9714 - val_accuracy: 0.4308 - val_loss: 3.6755 - val_top-5-accuracy: 0.6916
# Epoch 193/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8011 - loss: 1.5587 - top-5-accuracy: 0.9735 - val_accuracy: 0.4126 - val_loss: 3.8343 - val_top-5-accuracy: 0.6800
# Epoch 194/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8016 - loss: 1.5581 - top-5-accuracy: 0.9737 - val_accuracy: 0.4188 - val_loss: 3.6967 - val_top-5-accuracy: 0.6886
# Epoch 195/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8010 - loss: 1.5591 - top-5-accuracy: 0.9727 - val_accuracy: 0.4272 - val_loss: 3.7084 - val_top-5-accuracy: 0.6860
# Epoch 196/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8002 - loss: 1.5611 - top-5-accuracy: 0.9734 - val_accuracy: 0.4068 - val_loss: 3.7323 - val_top-5-accuracy: 0.6846
# Epoch 197/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8027 - loss: 1.5532 - top-5-accuracy: 0.9734 - val_accuracy: 0.3968 - val_loss: 3.9497 - val_top-5-accuracy: 0.6748
# Epoch 198/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8006 - loss: 1.5589 - top-5-accuracy: 0.9745 - val_accuracy: 0.4182 - val_loss: 3.7612 - val_top-5-accuracy: 0.6828
# Epoch 199/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8049 - loss: 1.5474 - top-5-accuracy: 0.9741 - val_accuracy: 0.4108 - val_loss: 3.8477 - val_top-5-accuracy: 0.6808
# Epoch 200/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8021 - loss: 1.5527 - top-5-accuracy: 0.9737 - val_accuracy: 0.4136 - val_loss: 3.7749 - val_top-5-accuracy: 0.6902
# Epoch 201/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8028 - loss: 1.5540 - top-5-accuracy: 0.9732 - val_accuracy: 0.4206 - val_loss: 3.7696 - val_top-5-accuracy: 0.6852
# Epoch 202/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8075 - loss: 1.5420 - top-5-accuracy: 0.9739 - val_accuracy: 0.4174 - val_loss: 3.7947 - val_top-5-accuracy: 0.6850
# Epoch 203/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8068 - loss: 1.5449 - top-5-accuracy: 0.9749 - val_accuracy: 0.4064 - val_loss: 3.8451 - val_top-5-accuracy: 0.6784
# Epoch 204/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8079 - loss: 1.5440 - top-5-accuracy: 0.9757 - val_accuracy: 0.4200 - val_loss: 3.6876 - val_top-5-accuracy: 0.6964
# Epoch 205/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8070 - loss: 1.5460 - top-5-accuracy: 0.9766 - val_accuracy: 0.4082 - val_loss: 3.8176 - val_top-5-accuracy: 0.6820
# Epoch 206/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.8094 - loss: 1.5409 - top-5-accuracy: 0.9744 - val_accuracy: 0.4202 - val_loss: 3.7420 - val_top-5-accuracy: 0.6908
# Epoch 207/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8089 - loss: 1.5391 - top-5-accuracy: 0.9755 - val_accuracy: 0.4170 - val_loss: 3.7432 - val_top-5-accuracy: 0.6872
# Epoch 208/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8151 - loss: 1.5282 - top-5-accuracy: 0.9766 - val_accuracy: 0.4014 - val_loss: 3.8815 - val_top-5-accuracy: 0.6752
# Epoch 209/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8089 - loss: 1.5398 - top-5-accuracy: 0.9745 - val_accuracy: 0.4182 - val_loss: 3.7196 - val_top-5-accuracy: 0.6960
# Epoch 210/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8067 - loss: 1.5418 - top-5-accuracy: 0.9755 - val_accuracy: 0.4264 - val_loss: 3.7025 - val_top-5-accuracy: 0.6890
# Epoch 211/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8118 - loss: 1.5327 - top-5-accuracy: 0.9763 - val_accuracy: 0.4308 - val_loss: 3.6778 - val_top-5-accuracy: 0.6964
# Epoch 212/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8118 - loss: 1.5309 - top-5-accuracy: 0.9762 - val_accuracy: 0.4054 - val_loss: 3.8421 - val_top-5-accuracy: 0.6818
# Epoch 213/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8098 - loss: 1.5356 - top-5-accuracy: 0.9762 - val_accuracy: 0.4132 - val_loss: 3.8675 - val_top-5-accuracy: 0.6832
# Epoch 214/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8165 - loss: 1.5251 - top-5-accuracy: 0.9775 - val_accuracy: 0.4260 - val_loss: 3.7050 - val_top-5-accuracy: 0.6924
# Epoch 215/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8103 - loss: 1.5333 - top-5-accuracy: 0.9771 - val_accuracy: 0.4058 - val_loss: 3.8695 - val_top-5-accuracy: 0.6792
# Epoch 216/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8190 - loss: 1.5131 - top-5-accuracy: 0.9783 - val_accuracy: 0.4254 - val_loss: 3.6693 - val_top-5-accuracy: 0.6854
# Epoch 217/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8141 - loss: 1.5232 - top-5-accuracy: 0.9752 - val_accuracy: 0.4184 - val_loss: 3.7535 - val_top-5-accuracy: 0.6866
# Epoch 218/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8243 - loss: 1.5091 - top-5-accuracy: 0.9788 - val_accuracy: 0.4190 - val_loss: 3.6864 - val_top-5-accuracy: 0.6842
# Epoch 219/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8205 - loss: 1.5167 - top-5-accuracy: 0.9781 - val_accuracy: 0.4090 - val_loss: 3.8371 - val_top-5-accuracy: 0.6840
# Epoch 220/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8206 - loss: 1.5101 - top-5-accuracy: 0.9797 - val_accuracy: 0.4098 - val_loss: 3.7534 - val_top-5-accuracy: 0.6866
# Epoch 221/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8192 - loss: 1.5172 - top-5-accuracy: 0.9764 - val_accuracy: 0.4174 - val_loss: 3.7289 - val_top-5-accuracy: 0.6862
# Epoch 222/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8174 - loss: 1.5209 - top-5-accuracy: 0.9774 - val_accuracy: 0.4226 - val_loss: 3.7094 - val_top-5-accuracy: 0.6918
# Epoch 223/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8173 - loss: 1.5144 - top-5-accuracy: 0.9777 - val_accuracy: 0.4352 - val_loss: 3.6601 - val_top-5-accuracy: 0.6930
# Epoch 224/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8191 - loss: 1.5123 - top-5-accuracy: 0.9796 - val_accuracy: 0.4154 - val_loss: 3.7419 - val_top-5-accuracy: 0.6786
# Epoch 225/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8241 - loss: 1.5067 - top-5-accuracy: 0.9782 - val_accuracy: 0.4182 - val_loss: 3.7532 - val_top-5-accuracy: 0.6868
# Epoch 226/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8280 - loss: 1.5015 - top-5-accuracy: 0.9794 - val_accuracy: 0.4194 - val_loss: 3.7874 - val_top-5-accuracy: 0.6896
# Epoch 227/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8249 - loss: 1.5010 - top-5-accuracy: 0.9805 - val_accuracy: 0.4296 - val_loss: 3.7283 - val_top-5-accuracy: 0.6916
# Epoch 228/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8233 - loss: 1.5050 - top-5-accuracy: 0.9790 - val_accuracy: 0.4254 - val_loss: 3.7050 - val_top-5-accuracy: 0.6852
# Epoch 229/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8258 - loss: 1.5012 - top-5-accuracy: 0.9786 - val_accuracy: 0.4120 - val_loss: 3.7721 - val_top-5-accuracy: 0.6820
# Epoch 230/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8281 - loss: 1.4935 - top-5-accuracy: 0.9808 - val_accuracy: 0.4220 - val_loss: 3.7083 - val_top-5-accuracy: 0.6924
# Epoch 231/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8225 - loss: 1.5004 - top-5-accuracy: 0.9804 - val_accuracy: 0.4208 - val_loss: 3.8400 - val_top-5-accuracy: 0.6768
# Epoch 232/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8322 - loss: 1.4830 - top-5-accuracy: 0.9816 - val_accuracy: 0.4310 - val_loss: 3.5717 - val_top-5-accuracy: 0.6950
# Epoch 233/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8298 - loss: 1.4953 - top-5-accuracy: 0.9804 - val_accuracy: 0.4338 - val_loss: 3.6499 - val_top-5-accuracy: 0.6864
# Epoch 234/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8292 - loss: 1.4906 - top-5-accuracy: 0.9805 - val_accuracy: 0.4256 - val_loss: 3.6841 - val_top-5-accuracy: 0.6850
# Epoch 235/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8243 - loss: 1.5028 - top-5-accuracy: 0.9796 - val_accuracy: 0.4234 - val_loss: 3.6721 - val_top-5-accuracy: 0.6842
# Epoch 236/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8300 - loss: 1.4904 - top-5-accuracy: 0.9799 - val_accuracy: 0.4208 - val_loss: 3.7210 - val_top-5-accuracy: 0.6866
# Epoch 237/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8229 - loss: 1.5023 - top-5-accuracy: 0.9791 - val_accuracy: 0.4252 - val_loss: 3.6645 - val_top-5-accuracy: 0.6852
# Epoch 238/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8296 - loss: 1.4845 - top-5-accuracy: 0.9824 - val_accuracy: 0.4284 - val_loss: 3.6776 - val_top-5-accuracy: 0.6934
# Epoch 239/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8332 - loss: 1.4887 - top-5-accuracy: 0.9830 - val_accuracy: 0.4230 - val_loss: 3.6777 - val_top-5-accuracy: 0.6884
# Epoch 240/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8303 - loss: 1.4848 - top-5-accuracy: 0.9810 - val_accuracy: 0.4308 - val_loss: 3.6979 - val_top-5-accuracy: 0.6846
# Epoch 241/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8321 - loss: 1.4853 - top-5-accuracy: 0.9816 - val_accuracy: 0.4312 - val_loss: 3.7113 - val_top-5-accuracy: 0.6926
# Epoch 242/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8307 - loss: 1.4851 - top-5-accuracy: 0.9818 - val_accuracy: 0.4580 - val_loss: 3.5115 - val_top-5-accuracy: 0.7094
# Epoch 243/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8324 - loss: 1.4781 - top-5-accuracy: 0.9820 - val_accuracy: 0.4438 - val_loss: 3.6046 - val_top-5-accuracy: 0.7014
# Epoch 244/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8373 - loss: 1.4730 - top-5-accuracy: 0.9832 - val_accuracy: 0.4336 - val_loss: 3.6826 - val_top-5-accuracy: 0.6836
# Epoch 245/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8367 - loss: 1.4756 - top-5-accuracy: 0.9819 - val_accuracy: 0.4392 - val_loss: 3.6522 - val_top-5-accuracy: 0.6960
# Epoch 246/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8370 - loss: 1.4734 - top-5-accuracy: 0.9817 - val_accuracy: 0.4448 - val_loss: 3.5298 - val_top-5-accuracy: 0.7082
# Epoch 247/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8392 - loss: 1.4708 - top-5-accuracy: 0.9818 - val_accuracy: 0.4358 - val_loss: 3.6496 - val_top-5-accuracy: 0.7018
# Epoch 248/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8392 - loss: 1.4663 - top-5-accuracy: 0.9844 - val_accuracy: 0.4340 - val_loss: 3.6137 - val_top-5-accuracy: 0.6928
# Epoch 249/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8385 - loss: 1.4718 - top-5-accuracy: 0.9834 - val_accuracy: 0.4356 - val_loss: 3.6101 - val_top-5-accuracy: 0.7032
# Epoch 250/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8380 - loss: 1.4731 - top-5-accuracy: 0.9812 - val_accuracy: 0.4352 - val_loss: 3.5821 - val_top-5-accuracy: 0.7034
# Epoch 251/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8380 - loss: 1.4757 - top-5-accuracy: 0.9821 - val_accuracy: 0.4310 - val_loss: 3.6649 - val_top-5-accuracy: 0.6868
# Epoch 252/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8333 - loss: 1.4831 - top-5-accuracy: 0.9795 - val_accuracy: 0.4416 - val_loss: 3.5478 - val_top-5-accuracy: 0.6964
# Epoch 253/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8375 - loss: 1.4668 - top-5-accuracy: 0.9828 - val_accuracy: 0.4382 - val_loss: 3.6024 - val_top-5-accuracy: 0.6942
# Epoch 254/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8388 - loss: 1.4646 - top-5-accuracy: 0.9840 - val_accuracy: 0.4390 - val_loss: 3.5945 - val_top-5-accuracy: 0.7022
# Epoch 255/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8415 - loss: 1.4656 - top-5-accuracy: 0.9820 - val_accuracy: 0.4284 - val_loss: 3.8111 - val_top-5-accuracy: 0.6890
# Epoch 256/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8390 - loss: 1.4703 - top-5-accuracy: 0.9826 - val_accuracy: 0.4428 - val_loss: 3.5742 - val_top-5-accuracy: 0.7138
# Epoch 257/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8414 - loss: 1.4636 - top-5-accuracy: 0.9825 - val_accuracy: 0.4296 - val_loss: 3.7012 - val_top-5-accuracy: 0.6876
# Epoch 258/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8343 - loss: 1.4801 - top-5-accuracy: 0.9811 - val_accuracy: 0.4352 - val_loss: 3.5872 - val_top-5-accuracy: 0.7012
# Epoch 259/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8416 - loss: 1.4643 - top-5-accuracy: 0.9832 - val_accuracy: 0.4476 - val_loss: 3.5310 - val_top-5-accuracy: 0.6986
# Epoch 260/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8401 - loss: 1.4675 - top-5-accuracy: 0.9840 - val_accuracy: 0.4382 - val_loss: 3.6078 - val_top-5-accuracy: 0.7118
# Epoch 261/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8344 - loss: 1.4721 - top-5-accuracy: 0.9824 - val_accuracy: 0.4400 - val_loss: 3.6678 - val_top-5-accuracy: 0.6906
# Epoch 262/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8353 - loss: 1.4706 - top-5-accuracy: 0.9814 - val_accuracy: 0.4360 - val_loss: 3.6565 - val_top-5-accuracy: 0.7046
# Epoch 263/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8452 - loss: 1.4567 - top-5-accuracy: 0.9835 - val_accuracy: 0.4324 - val_loss: 3.6777 - val_top-5-accuracy: 0.7004
# Epoch 264/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8450 - loss: 1.4516 - top-5-accuracy: 0.9841 - val_accuracy: 0.4490 - val_loss: 3.5908 - val_top-5-accuracy: 0.7098
# Epoch 265/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8441 - loss: 1.4614 - top-5-accuracy: 0.9838 - val_accuracy: 0.4578 - val_loss: 3.4987 - val_top-5-accuracy: 0.7138
# Epoch 266/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8478 - loss: 1.4499 - top-5-accuracy: 0.9853 - val_accuracy: 0.4568 - val_loss: 3.4428 - val_top-5-accuracy: 0.7180
# Epoch 267/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8438 - loss: 1.4547 - top-5-accuracy: 0.9843 - val_accuracy: 0.4532 - val_loss: 3.5194 - val_top-5-accuracy: 0.7132
# Epoch 268/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8392 - loss: 1.4561 - top-5-accuracy: 0.9838 - val_accuracy: 0.4354 - val_loss: 3.6068 - val_top-5-accuracy: 0.7074
# Epoch 269/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8467 - loss: 1.4490 - top-5-accuracy: 0.9851 - val_accuracy: 0.4500 - val_loss: 3.5710 - val_top-5-accuracy: 0.7146
# Epoch 270/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8409 - loss: 1.4528 - top-5-accuracy: 0.9844 - val_accuracy: 0.4434 - val_loss: 3.5461 - val_top-5-accuracy: 0.7120
# Epoch 271/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8500 - loss: 1.4404 - top-5-accuracy: 0.9864 - val_accuracy: 0.4294 - val_loss: 3.6865 - val_top-5-accuracy: 0.6920
# Epoch 272/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8465 - loss: 1.4449 - top-5-accuracy: 0.9857 - val_accuracy: 0.4516 - val_loss: 3.5837 - val_top-5-accuracy: 0.7094
# Epoch 273/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8458 - loss: 1.4519 - top-5-accuracy: 0.9833 - val_accuracy: 0.4554 - val_loss: 3.5269 - val_top-5-accuracy: 0.7098
# Epoch 274/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8490 - loss: 1.4456 - top-5-accuracy: 0.9844 - val_accuracy: 0.4578 - val_loss: 3.4540 - val_top-5-accuracy: 0.7164
# Epoch 275/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8474 - loss: 1.4474 - top-5-accuracy: 0.9841 - val_accuracy: 0.4514 - val_loss: 3.5651 - val_top-5-accuracy: 0.7116
# Epoch 276/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8500 - loss: 1.4383 - top-5-accuracy: 0.9844 - val_accuracy: 0.4558 - val_loss: 3.5276 - val_top-5-accuracy: 0.7206
# Epoch 277/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8467 - loss: 1.4431 - top-5-accuracy: 0.9847 - val_accuracy: 0.4496 - val_loss: 3.4737 - val_top-5-accuracy: 0.7166
# Epoch 278/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8528 - loss: 1.4312 - top-5-accuracy: 0.9862 - val_accuracy: 0.4498 - val_loss: 3.4946 - val_top-5-accuracy: 0.7050
# Epoch 279/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8501 - loss: 1.4313 - top-5-accuracy: 0.9867 - val_accuracy: 0.4530 - val_loss: 3.4794 - val_top-5-accuracy: 0.7136
# Epoch 280/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8458 - loss: 1.4455 - top-5-accuracy: 0.9847 - val_accuracy: 0.4430 - val_loss: 3.5474 - val_top-5-accuracy: 0.7046
# Epoch 281/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8451 - loss: 1.4454 - top-5-accuracy: 0.9843 - val_accuracy: 0.4510 - val_loss: 3.5208 - val_top-5-accuracy: 0.7130
# Epoch 282/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8493 - loss: 1.4376 - top-5-accuracy: 0.9858 - val_accuracy: 0.4558 - val_loss: 3.5283 - val_top-5-accuracy: 0.7084
# Epoch 283/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8485 - loss: 1.4489 - top-5-accuracy: 0.9828 - val_accuracy: 0.4460 - val_loss: 3.5520 - val_top-5-accuracy: 0.7070
# Epoch 284/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8495 - loss: 1.4352 - top-5-accuracy: 0.9860 - val_accuracy: 0.4576 - val_loss: 3.4642 - val_top-5-accuracy: 0.7194
# Epoch 285/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8528 - loss: 1.4315 - top-5-accuracy: 0.9859 - val_accuracy: 0.4484 - val_loss: 3.5188 - val_top-5-accuracy: 0.7108
# Epoch 286/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8505 - loss: 1.4380 - top-5-accuracy: 0.9867 - val_accuracy: 0.4532 - val_loss: 3.4784 - val_top-5-accuracy: 0.7210
# Epoch 287/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8541 - loss: 1.4268 - top-5-accuracy: 0.9857 - val_accuracy: 0.4460 - val_loss: 3.5281 - val_top-5-accuracy: 0.7160
# Epoch 288/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8530 - loss: 1.4344 - top-5-accuracy: 0.9867 - val_accuracy: 0.4574 - val_loss: 3.4643 - val_top-5-accuracy: 0.7160
# Epoch 289/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8551 - loss: 1.4267 - top-5-accuracy: 0.9861 - val_accuracy: 0.4510 - val_loss: 3.4642 - val_top-5-accuracy: 0.7210
# Epoch 290/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8516 - loss: 1.4356 - top-5-accuracy: 0.9847 - val_accuracy: 0.4576 - val_loss: 3.4902 - val_top-5-accuracy: 0.7190
# Epoch 291/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8504 - loss: 1.4369 - top-5-accuracy: 0.9853 - val_accuracy: 0.4578 - val_loss: 3.4599 - val_top-5-accuracy: 0.7134
# Epoch 292/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8533 - loss: 1.4258 - top-5-accuracy: 0.9874 - val_accuracy: 0.4582 - val_loss: 3.4275 - val_top-5-accuracy: 0.7162
# Epoch 293/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.8536 - loss: 1.4307 - top-5-accuracy: 0.9855 - val_accuracy: 0.4526 - val_loss: 3.5251 - val_top-5-accuracy: 0.7120
# Epoch 294/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8529 - loss: 1.4320 - top-5-accuracy: 0.9849 - val_accuracy: 0.4580 - val_loss: 3.3900 - val_top-5-accuracy: 0.7204
# Epoch 295/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8525 - loss: 1.4307 - top-5-accuracy: 0.9866 - val_accuracy: 0.4560 - val_loss: 3.4457 - val_top-5-accuracy: 0.7138
# Epoch 296/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8511 - loss: 1.4332 - top-5-accuracy: 0.9865 - val_accuracy: 0.4596 - val_loss: 3.4540 - val_top-5-accuracy: 0.7128
# Epoch 297/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8558 - loss: 1.4243 - top-5-accuracy: 0.9862 - val_accuracy: 0.4552 - val_loss: 3.4623 - val_top-5-accuracy: 0.7182
# Epoch 298/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8523 - loss: 1.4281 - top-5-accuracy: 0.9870 - val_accuracy: 0.4578 - val_loss: 3.4171 - val_top-5-accuracy: 0.7244
# Epoch 299/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8561 - loss: 1.4212 - top-5-accuracy: 0.9867 - val_accuracy: 0.4530 - val_loss: 3.4858 - val_top-5-accuracy: 0.7070
# Epoch 300/300
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.8593 - loss: 1.4185 - top-5-accuracy: 0.9870 - val_accuracy: 0.4504 - val_loss: 3.5771 - val_top-5-accuracy: 0.7070
# CPU times: user 3h 50min 27s, sys: 7min 34s, total: 3h 58min 1s
# Wall time: 2h 17min 56s

# %%
# 損失（loss）のプロット
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()

# 正解率（accuracy）のプロット
plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="train_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy Over Epochs", fontsize=14)
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
loss, accuracy, top_5_accuracy = model.evaluate(dataset_test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4598 - loss: 3.5532 - top-5-accuracy: 0.7156
# Test loss: 3.53
# Test accuracy: 46.33%
# Test top 5 accuracy: 71.56%
