# %%
#
# !git init
# !git remote add origin https://github.com/noriaki555/your-repo
# Out:
# Reinitialized existing Git repository in /content/.git/
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://github.com/noriaki555/your-repo (fetch)
# origin	https://github.com/noriaki555/your-repo (push)

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/noriaki555/your-repo'

# %% [markdown]
# # 第10章 性能評価

# %% [markdown]
# ## 10.2 評価指標を用いた自動評価

# %% [markdown]
# ### 10.2.2 llm-jp-evalで扱うタスク

# %%
# !pip install datasets rhoknp xmltodict
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ...

# %% [markdown]
# #### 自然言語推論

# %%
from pprint import pprint
from datasets import load_dataset

dataset = load_dataset("llm-book/llm-jp-eval", "jamp")
pprint(list(dataset["train"])[0])
print("ラベルの種類:", set(dataset["train"]["output"]))
# Out:
# ...
# The repository for llm-book/llm-jp-eval contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/llm-book/llm-jp-eval.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Start processing jamp
# Finish downloading jamp
# Finish preprocessing evaluation data of jamp
# Finish preprocessing tuning data of jamp
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '前提：8月以来、ゾーイは雑誌に発表している。現在、10月である。\n仮説：ゾーイは9月には雑誌に発表していた。',
#  'output': 'entailment'}
# ラベルの種類: {'contradiction', 'neutral', 'entailment'}

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "janli")
pprint(list(dataset["train"])[0])
print("ラベルの種類:", set(dataset["train"]["output"]))
# Out:
# Start processing janli
# Finish downloading janli
# Finish preprocessing evaluation data of janli
# Finish preprocessing tuning data of janli
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '前提：スノーボーダーが子供を見ている大人をいじめている\n仮説：スノーボーダーが大人をいじめている',
#  'output': 'entailment'}
# ラベルの種類: {'entailment', 'non-entailment'}

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jnli")
pprint(list(dataset["train"])[0])
print("ラベルの種類:", set(dataset["train"]["output"]))
# Out:
# Start processing jnli
# Finish downloading jnli
# Finish preprocessing evaluation data of jnli
# Finish preprocessing tuning data of jnli
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '前提：壁側のすみっこに布団が畳んでおいてあります。\n仮説：畳の上のすみに、布団がたたまれて置いてあります。',
#  'output': 'neutral'}
# ラベルの種類: {'contradiction', 'neutral', 'entailment'}

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jsem")
pprint(list(dataset["train"])[0])
print("ラベルの種類:", set(dataset["train"]["output"]))
# Out:
# Start processing jsem
# Finish downloading jsem
# Finish preprocessing evaluation data of jsem
# Finish preprocessing tuning data of jsem
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '前提：難しい数学の問題がやっと解けた。\n仮説：難しい数学の問題が解けた。', 'output': 'yes'}
# ラベルの種類: {'no', 'undef', 'yes', 'unknown'}

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jsick")
pprint(list(dataset["train"])[0])
print("ラベルの種類:", set(dataset["train"]["output"]))
# Out:
# Start processing jsick
# Finish downloading jsick
# Finish preprocessing evaluation data of jsick
# Finish preprocessing tuning data of jsick
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '前提：二人の子供がカラフルなボールの上に座っている\n仮説：子供たちは黒いタイツを着ていて、びょんびょん跳んでいる',
#  'output': 'neutral'}
# ラベルの種類: {'contradiction', 'neutral', 'entailment'}

# %% [markdown]
# #### 質問応答

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jemhopqa")
pprint(list(dataset["train"])[0])
# Out:
# Start processing jemhopqa
# Finish downloading jemhopqa
# Finish preprocessing evaluation data of jemhopqa
# Finish preprocessing tuning data of jemhopqa
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '質問：映画『ダイ・ハード』と『デッドプール2』のうち、公開年が早いほうはどっち？', 'output': 'ダイ・ハード'}

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "niilc")
pprint(list(dataset["train"])[0])
# Out:
# Start processing niilc
# Finish downloading niilc
# Finish preprocessing evaluation data of niilc
# Finish preprocessing tuning data of niilc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '質問：種にどくが含まれていると言われる果物は？', 'output': 'モモ'}

# %% [markdown]
# #### 機械読解

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jsquad")
pprint(list(dataset["train"])[0])
# Out:
# Start processing jsquad
# Finish downloading jsquad
# Finish preprocessing evaluation data of jsquad
# Finish preprocessing tuning data of jsquad
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '文章：測量 [SEP] '
#           '多くの測量では地表上の位置を計算するのではなく、オブジェクトの相対位置を測定していた。ただし、多くの場合に対象のアイテムは、境界線や以前の測量時のオブジェクトなどの外部データと比較する必要がある。\n'
#           '質問：多くの測量では、オブジェクトの何を測定していたか',
#  'output': '相対位置'}

# %% [markdown]
# #### 多肢選択式質問応答

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jcommonsenseqa")
pprint(list(dataset["train"])[0])
# Out:
# Start processing jcommonsenseqa
# Finish downloading jcommonsenseqa
# Finish preprocessing evaluation data of jcommonsenseqa
# Finish preprocessing tuning data of jcommonsenseqa
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '質問：動物たちの餌になるものは？\n選択肢：0.猫,1.家畜,2.原宿,3.牧草,4.島根県', 'output': '3'}

# %% [markdown]
# #### エンティティ極性分析

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "chabsa")
pprint(list(dataset["train"])[0])
# Out:
# Start processing chabsa
# Finish downloading chabsa
# Finish preprocessing evaluation data of chabsa
# Finish preprocessing tuning data of chabsa
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '文章：その結果、当連結会計年度の業績につきましては、営業収益103億41百万円（前期比101.2％）、純営業収益102億10百万円（同101.0％）、経常利益47億35百万円（同110.7％）、親会社株主に帰属する当期純利益46億88百万円（同163.5％）となりました',
#  'output': '営業収益 positive\n純営業収益 positive\n経常利益 positive\n当期純利益 positive'}

# %% [markdown]
# #### 基礎解析

# %% [markdown]
# 読み推定

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "wiki_reading")
pprint(list(dataset["train"])[0])
# Out:
# Start processing wiki_reading
# Finish downloading wiki_reading
# Finish preprocessing evaluation data of wiki_reading
# Finish preprocessing tuning data of wiki_reading
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': 'インダクタンスは、コイルなどにおいて電流の変化が誘導起電力となって現れる性質である。誘導係数、誘導子とも言う。インダクタンスを目的とするコイルをインダクタといい、それに使用する導線を巻線という。',
#  'output': 'いんだくたんすは、こいるなどにおいてでんりゅうのへんかがゆうどうきでんりょくとなってあらわれるせいしつである。ゆうどうけいすう、ゆうどうしともいう。いんだくたんすをもくてきとするこいるをいんだくたといい、それにしようするどうせんをまきせんという。'}

# %% [markdown]
# 固有表現認識

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "wiki_ner")
pprint(list(dataset["train"])[0])
# Out:
# Start processing wiki_ner
# Finish downloading wiki_ner
# Finish preprocessing evaluation data of wiki_ner
# Finish preprocessing tuning data of wiki_ner
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': 'ナウル共和国（ナウルきょうわこく）、通称ナウルは、太平洋南西部に位置するナウル島にある共和国である。',
#  'output': 'ナウル共和国（地名） ナウル（地名） 太平洋（地名） ナウル島（地名） ナウルきょうわこく（地名）'}

# %% [markdown]
# 依存構造解析

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "wiki_dependency")
pprint(list(dataset["train"])[0])
# Out:
# Start processing wiki_dependency
# Finish downloading wiki_dependency
# Finish preprocessing evaluation data of wiki_dependency
# Finish preprocessing tuning data of wiki_dependency
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': 'インダクタンスは、コイルなどにおいて電流の変化が誘導起電力となって現れる性質である。誘導係数、誘導子とも言う。インダクタンスを目的とするコイルをインダクタといい、それに使用する導線を巻線という。',
#  'output': 'インダクタンスは、 -> 性質である。\n'
#            'コイルなどに -> おいて\n'
#            'おいて -> 現れる\n'
#            '電流の -> 変化が\n'
#            '変化が -> なって\n'
#            '誘導起電力と -> なって\n'
#            'なって -> 現れる\n'
#            '現れる -> 性質である。\n'
#            '誘導係数、 -> 誘導子とも\n'
#            '誘導子とも -> 言う。\n'
#            'インダクタンスを -> する\n'
#            '目的と -> する\n'
#            'する -> コイルを\n'
#            'コイルを -> いい、\n'
#            'インダクタと -> いい、\n'
#            'いい、 -> いう。\n'
#            'それに -> 使用する\n'
# ...

# %% [markdown]
# 述語構造解析

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "wiki_pas")
pprint(list(dataset["train"])[0])
# Out:
# Start processing wiki_pas
# Finish downloading wiki_pas
# Finish preprocessing evaluation data of wiki_pas
# Finish preprocessing tuning data of wiki_pas
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': 'インダクタンスは、コイルなどにおいて電流の変化が誘導起電力となって現れる性質である。誘導係数、誘導子とも言う。インダクタンスを目的とするコイルをインダクタといい、それに使用する導線を巻線という。',
#  'output': '変化 ガ：電流\n'
#            '誘導起電力 ガ：変化\n'
#            'なって ガ：変化 ト：誘導起電力\n'
#            '現れる ガ：性質\n'
#            '性質である ガ：インダクタンス\n'
#            '言う ト：誘導係数 ト：誘導子 ヲ：インダクタンス\n'
#            'する ガ：コイル ト：目的 ヲ：インダクタンス\n'
#            'いい ト：インダクタ ヲ：コイル\n'
#            '使用する ニ：それ ヲ：導線\n'
#            'いう ト：巻線 ヲ：導線'}

# %% [markdown]
# 共参照解析

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "wiki_coreference")
pprint(list(dataset["train"])[0])
# Out:
# Start processing wiki_coreference
# Finish downloading wiki_coreference
# Finish preprocessing evaluation data of wiki_coreference
# Finish preprocessing tuning data of wiki_coreference
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': 'インダクタンスは、コイルなどにおいて電流の変化が誘導起電力となって現れる性質である。誘導係数、誘導子とも言う。インダクタンスを目的とするコイルをインダクタといい、それに使用する導線を巻線という。',
#  'output': 'インダクタンス 性質 誘導係数 誘導子 インダクタンス 目的\nコイル コイル インダクタ それ\n誘導 誘導 誘導\n導線 巻線'}

# %% [markdown]
# #### 数学的推論

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "mawps")
pprint(list(dataset["train"])[0])
# Out:
# Start processing mawps
# Finish downloading mawps
# Finish preprocessing evaluation data of mawps
# Finish preprocessing tuning data of mawps
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '問題：佐藤は16個の青い風船、鈴木は11個の青い風船、高橋は99個の青い風船を持っています。彼らは全部でいくつの青い風船を持っているのでしょう？',
#  'output': '126'}

# %% [markdown]
# #### 意味的類似度計算

# %%
dataset = load_dataset("llm-book/llm-jp-eval", "jsts")
pprint(list(dataset["train"])[0])
# Out:
# Start processing jsts
# Finish downloading jsts
# Finish preprocessing evaluation data of jsts
# Finish preprocessing tuning data of jsts
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# {'input': '文1：牧草地に放牧された家畜がたくさんいます。\n文2：草原にたくさんの動物たちがいます。', 'output': '2.2'}
