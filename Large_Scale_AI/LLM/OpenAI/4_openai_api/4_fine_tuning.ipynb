# %% [markdown]
# # OpenAI APIの前準備

# %%
# パッケージのインストール
# !pip install openai

# %%
import os
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
print(OPENAI_API_KEY)
# Out:
# None

# %% [markdown]
# APIKey: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

# %%
# 環境変数の準備
import os
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# # 学習データの準備

# %%
import pandas as pd

# データセットの準備
df = pd.read_csv(
    '/content/drive/MyDrive/tsukuyomi.csv',
    usecols=[1,2],
    names=['prompt','completion'],
    skiprows=2)
df.to_json(
    "tsukuyomi.jsonl",
    orient='records',
    lines=True,
    force_ascii=False
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットの検証
# !openai tools fine_tunes.prepare_data \
    -f tsukuyomi.jsonl \
    -q
# Out:
# Analyzing...
#
# - Your file contains 512 prompt-completion pairs
# - There are 2 duplicated prompt-completion sets. These are rows: [481, 482]
# - More than a third of your `prompt` column/key is uppercase. Uppercase prompts tends to perform worse than a mixture of case encountered in normal language. We recommend to lower case the data if that makes sense in your domain. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
# - More than a third of your `completion` column/key is uppercase. Uppercase completions tends to perform worse than a mixture of case encountered in normal language. We recommend to lower case the data if that makes sense in your domain. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
# ...

# %%
# !openai tools fine_tunes.prepare_data \
    -f tsukuyomi.jsonl \
    -q
# Out:
# Analyzing...
#
# - Your file contains 512 prompt-completion pairs
# - There are 2 duplicated prompt-completion sets. These are rows: [481, 482]
# - More than a third of your `prompt` column/key is uppercase. Uppercase prompts tends to perform worse than a mixture of case encountered in normal language. We recommend to lower case the data if that makes sense in your domain. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
# - More than a third of your `completion` column/key is uppercase. Uppercase completions tends to perform worse than a mixture of case encountered in normal language. We recommend to lower case the data if that makes sense in your domain. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
# ...

# %% [markdown]
# # ファインチューニングの実行

# %%
# ファインチューニングの実行
# !openai api fine_tunes.create \
    -t "/content/tsukuyomiprepared.jsonl" \
    -m GPT-4
# Out:
# usage: openai api [-h]
#                   {chat.completions.create,images.generate,images.edit,images.create_variation,audio.transcriptions.create,audio.translations.create,files.create,files.retrieve,files.delete,files.list,models.list,models.retrieve,models.delete,completions.create}
#                   ...
# openai api: error: argument {chat.completions.create,images.generate,images.edit,images.create_variation,audio.transcriptions.create,audio.translations.create,files.create,files.retrieve,files.delete,files.list,models.list,models.retrieve,models.delete,completions.create}: invalid choice: 'fine_tunes.create' (choose from 'chat.completions.create', 'images.generate', 'images.edit', 'images.create_variation', 'audio.transcriptions.create', 'audio.translations.create', 'files.create', 'files.retrieve', 'files.delete', 'files.list', 'models.list', 'models.retrieve', 'models.delete', 'completions.create')

# %%
# ファインチューニングのジョブの確認
# !openai api fine_tunes.get \
    -i ft-ElEoXDioUUTHHm3lxUmYIr2D
# Out:
# usage: openai api [-h]
#                   {chat.completions.create,images.generate,images.edit,images.create_variation,audio.transcriptions.create,audio.translations.create,files.create,files.retrieve,files.delete,files.list,models.list,models.retrieve,models.delete,completions.create}
#                   ...
# openai api: error: argument {chat.completions.create,images.generate,images.edit,images.create_variation,audio.transcriptions.create,audio.translations.create,files.create,files.retrieve,files.delete,files.list,models.list,models.retrieve,models.delete,completions.create}: invalid choice: 'fine_tunes.get' (choose from 'chat.completions.create', 'images.generate', 'images.edit', 'images.create_variation', 'audio.transcriptions.create', 'audio.translations.create', 'files.create', 'files.retrieve', 'files.delete', 'files.list', 'models.list', 'models.retrieve', 'models.delete', 'completions.create')

# %% [markdown]
# # 推論の実行

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.84.0
#     Uninstalling openai-1.84.0:
#       Successfully uninstalled openai-1.84.0
# ...

# %%
import openai

# 推論の実行
prompt="好きな食べ物は何？->"
response = openai.Completion.create(
    model="<モデルID>",
    prompt=prompt,
    max_tokens=100,
    stop="\n")
print(response["choices"][0]["text"])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-4-3394267880> in <cell line: 0>()
#       3 # 推論の実行
#       4 prompt="好きな食べ物は何？->"
# ----> 5 response = openai.Completion.create(
#       6     model="<モデルID>",
#       7     prompt=prompt,
#
# /usr/local/lib/python3.11/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.11/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     147             url,
#     148             params,
# ...

# %% [markdown]
# # ファインチューニングモデルの一覧取得と削除

# %%
# ファインチューニングモデル一覧確認
# !openai api fine_tunes.list
# Out:
# Error: HTTP code 404 from API (<html>
# <head><title>404 Not Found</title></head>
# <body>
# <center><h1>404 Not Found</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
# ) (HTTP status code: 404)

# %%
# ファインチューニングモデルの削除
# !openai api models.delete \
    -i <モデルID>
