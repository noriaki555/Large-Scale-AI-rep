# %% [markdown]
# # OpenAI APIの前準備

# %%
# パッケージのインポート
# !pip install openai

# %%
# 環境変数の準備
import os
os.environ["OPENAI_API_KEY"] = "<OpenAI_APIのAPIキー>"

# %% [markdown]
# # モデレーションの利用手順

# %%
import openai

# モデレーションの利用
response = openai.Moderation.create(
    input="お前を殺す!"
)
print(response)

# %%
print(response)
