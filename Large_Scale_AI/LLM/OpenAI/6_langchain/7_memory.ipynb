# %% [markdown]
# # LangChainの準備

# %%
# パッケージのインストール
#!pip install langchain==0.0.181
# !pip install --uprade langchain
# !pip install openai
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --uprade
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.10.22)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.5.0->openai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)

# %%
# 環境変数の準備
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
# パッケージのインストール
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.4.26)

# %% [markdown]
# # ConversationBufferMemory

# %%
from langchain.memory import ConversationBufferMemory

# メモリの作成
memory = ConversationBufferMemory()
memory.chat_memory.add_user_message("おなかすいた")
memory.chat_memory.add_ai_message("どこか食べに行く？")
memory.chat_memory.add_user_message("ラーメン屋に行こう")
memory.chat_memory.add_ai_message("駅前のラーメン屋だね")
memory.chat_memory.add_user_message("それでは出発！")
memory.chat_memory.add_ai_message("OK！")

# %%
# メモリ変数の取得
memory.load_memory_variables({})
# Out:
# {'history': 'Human: おなかすいた\nAI: どこか食べに行く？\nHuman: ラーメン屋に行こう\nAI: 駅前のラーメン屋だね\nHuman: それでは出発！\nAI: OK！'}

# %%
from langchain.memory import ConversationBufferMemory

# メモリの作成
memory = ConversationBufferMemory(return_messages=True)
memory.chat_memory.add_user_message("おなかすいた")
memory.chat_memory.add_ai_message("どこか食べに行く？")
memory.chat_memory.add_user_message("ラーメン屋に行こう")
memory.chat_memory.add_ai_message("駅前のラーメン屋だね")
memory.chat_memory.add_user_message("それでは出発！")
memory.chat_memory.add_ai_message("OK！")

# %%
# メモリ変数の取得
memory.load_memory_variables({})
# Out:
# {'history': [HumanMessage(content='おなかすいた', additional_kwargs={}, example=False),
#   AIMessage(content='どこか食べに行く？', additional_kwargs={}, example=False),
#   HumanMessage(content='ラーメン屋に行こう', additional_kwargs={}, example=False),
#   AIMessage(content='駅前のラーメン屋だね', additional_kwargs={}, example=False),
#   HumanMessage(content='それでは出発！', additional_kwargs={}, example=False),
#   AIMessage(content='OK！', additional_kwargs={}, example=False)]}

# %% [markdown]
# # ConversationBufferWindowMemory

# %%
from langchain.memory import ConversationBufferWindowMemory

# メモリの作成
memory = ConversationBufferWindowMemory(k=2, return_messages=True)
memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
memory.save_context({"input": "それでは出発！"}, {"ouput": "OK！"})

# %%
# メモリ変数の取得
memory.load_memory_variables({})
# Out:
# {'history': [HumanMessage(content='ラーメン屋に行こう', additional_kwargs={}, example=False),
#   AIMessage(content='駅前のラーメン屋だね', additional_kwargs={}, example=False),
#   HumanMessage(content='それでは出発！', additional_kwargs={}, example=False),
#   AIMessage(content='OK！', additional_kwargs={}, example=False)]}

# %% [markdown]
# # ConversationTokenBufferMemory

# %%
from langchain.memory import ConversationTokenBufferMemory
from langchain.chat_models import ChatOpenAI

# メモリの作成
memory = ConversationTokenBufferMemory(
    llm=ChatOpenAI(temperature=0),
    max_token_limit=50,
    return_messages=True
)
memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
memory.save_context({"input": "それでは出発！"}, {"ouput": "OK！"})

# %%
# メモリ変数の取得
memory.load_memory_variables({})
# Out:
# {'history': [AIMessage(content='駅前のラーメン屋だね', additional_kwargs={}, example=False),
#   HumanMessage(content='それでは出発！', additional_kwargs={}, example=False),
#   AIMessage(content='OK！', additional_kwargs={}, example=False)]}

# %% [markdown]
# # ConversationSummaryMemory

# %%
# !pip uninstall -y langchain openai
# !pip install langchain==0.1.0  # Example of a more recent version
# !pip install openai==1.0.0    # Example of a more recent version
# Out:
# Found existing installation: langchain 0.1.0
# Uninstalling langchain-0.1.0:
#   Successfully uninstalled langchain-0.1.0
# Found existing installation: openai 1.0.0
# Uninstalling openai-1.0.0:
#   Successfully uninstalled openai-1.0.0
# Collecting langchain==0.1.0
#   Using cached langchain-0.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (3.11.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (0.1.23)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (1.10.22)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.0) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.0) (3.0.0)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.2,>=0.1.7->langchain==0.1.0) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.2,>=0.1.7->langchain==0.1.0) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain==0.1.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.0) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.0) (3.2.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.7->langchain==0.1.0) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (1.1.0)
# Using cached langchain-0.1.0-py3-none-any.whl (797 kB)
# Installing collected packages: langchain
# Successfully installed langchain-0.1.0
# Collecting openai==1.0.0
#   Using cached openai-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (1.10.22)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.11/dist-packages (from openai==1.0.0) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.5.0->openai==1.0.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.5.0->openai==1.0.0) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai==1.0.0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai==1.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.0.0) (0.16.0)
# Using cached openai-1.0.0-py3-none-any.whl (154 kB)
# Installing collected packages: openai
# Successfully installed openai-1.0.0

# %%
# パッケージのインストール
# Older versions might have compatibility issues, so let's install the latest
# !pip uninstall -y langchain openai
# !pip install --upgrade langchain openai

# Ensure other necessary packages are installed
# !pip install tiktoken
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.1.0)
# Collecting langchain
#   Downloading langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Collecting openai
#   Downloading openai-1.79.0-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-core<1.0.0,>=0.3.58 (from langchain)
#   Downloading langchain_core-0.3.60-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.42-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Downloading langchain-0.3.25-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.7 MB/s eta 0:00:00
# Downloading openai-1.79.0-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.3/683.3 kB 33.4 MB/s eta 0:00:00
# Downloading langchain_core-0.3.60-py3-none-any.whl (437 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.9/437.9 kB 27.7 MB/s eta 0:00:00
# Downloading langsmith-0.3.42-py3-none-any.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.3/360.3 kB 23.6 MB/s eta 0:00:00
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 25.2 MB/s eta 0:00:00
# Installing collected packages: pydantic, openai, langsmith, langchain-core, langchain
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.22
#     Uninstalling pydantic-1.10.22:
#       Successfully uninstalled pydantic-1.10.22
#   Attempting uninstall: openai
#     Found existing installation: openai 1.0.0
#     Uninstalling openai-1.0.0:
#       Successfully uninstalled openai-1.0.0
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.87
#     Uninstalling langsmith-0.0.87:
#       Successfully uninstalled langsmith-0.0.87
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.23
#     Uninstalling langchain-core-0.1.23:
#       Successfully uninstalled langchain-core-0.1.23
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.0
#     Uninstalling langchain-0.1.0:
#       Successfully uninstalled langchain-0.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.0.20 requires langchain-core<0.2,>=0.1.21, but you have langchain-core 0.3.60 which is incompatible.
# langchain-community 0.0.20 requires langsmith<0.1,>=0.0.83, but you have langsmith 0.3.42 which is incompatible.
# google-genai 1.15.0 requires anyio<5.0.0,>=4.8.0, but you have anyio 3.7.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed langchain-0.3.25 langchain-core-0.3.60 langsmith-0.3.42 openai-1.79.0 pydantic-2.11.4
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.4.26)

# %%
from langchain.memory import ConversationSummaryMemory
from langchain.chat_models import ChatOpenAI
import os

# Unset potential proxy environment variables that might interfere
# This is a common cause of the 'proxies' keyword error in some library versions
#if 'HTTP_PROXY' in os.environ:
#    del os.environ['HTTP_PROXY']
#if 'HTTPS_PROXY' in os.environ:
#    del os.environ['HTTPS_PROXY']
#if 'ALL_PROXY' in os.environ:
#    del os.environ['ALL_PROXY']
#if 'NO_PROXY' in os.environ:
#    del os.environ['NO_PROXY']

# メモリの作成
memory = ConversationSummaryMemory(llm=ChatOpenAI(temperature=0), return_messages=True)
memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
memory.save_context({"input": "それでは出発！"}, {"ouput": "OK！"})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-10-aeba6b204277> in <cell line: 0>()
#      15
#      16 # メモリの作成
# ---> 17 memory = ConversationSummaryMemory(llm=ChatOpenAI(temperature=0), return_messages=True)
#      18 memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
#      19 memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     178             """Wrapper for the original wrapped callable that emits a warning.
#     179
# --> 180             Args:
#     181                 *args: The positional arguments to the function.
#     182                 **kwargs: The keyword arguments to the function.
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/load/serializable.py in __init__(self, **kwargs)
#     105 class Serializable(BaseModel, ABC):
#     106     """Serializable base class.
# --> 107
#     108     This class is used to serialize objects to JSON.
#     109
#
# /usr/local/lib/python3.11/dist-packages/pydantic/main.cpython-311-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for ChatOpenAI
# __root__
#   Client.__init__() got an unexpected keyword argument 'proxies' (type=type_error)

# %%
# メモリ変数の取得
memory.load_memory_variables({})

# %% [markdown]
# # ConversationSummaryBufferMemory

# %%
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chat_models import ChatOpenAI

# メモリの作成
memory = ConversationSummaryBufferMemory(
    llm=ChatOpenAI(temperature=0),
    max_token_limit=50,
    return_messages=True
)
memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
memory.save_context({"input": "それでは出発！"}, {"ouput": "OK！"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1ab4ccdffe30> in <cell line: 0>()
#       9 )
#      10 memory.save_context({"input": "おなかすいた"}, {"ouput": "どこか食べに行く？"})
# ---> 11 memory.save_context({"input": "ラーメン屋に行こう"}, {"ouput": "駅前のラーメン屋だね"})
#      12 memory.save_context({"input": "それでは出発！"}, {"ouput": "OK！"})
#
# /usr/local/lib/python3.11/dist-packages/langchain/memory/summary_buffer.py in save_context(self, inputs, outputs)
#      58         """Save context from this conversation to buffer."""
#      59         super().save_context(inputs, outputs)
# ---> 60         self.prune()
#      61
#      62     def prune(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/langchain/memory/summary_buffer.py in prune(self)
#      69                 pruned_memory.append(buffer.pop(0))
#      70                 curr_buffer_length = self.llm.get_num_tokens_from_messages(buffer)
# ---> 71             self.moving_summary_buffer = self.predict_new_summary(
#      72                 pruned_memory, self.moving_summary_buffer
#      73             )
#
# /usr/local/lib/python3.11/dist-packages/langchain/memory/summary.py in predict_new_summary(self, messages, existing_summary)
#      35
#      36         chain = LLMChain(llm=self.llm, prompt=self.prompt)
# ---> 37         return chain.predict(summary=existing_summary, new_lines=new_lines)
#      38
#      39
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     211                 completion = llm.predict(adjective="funny")
#     212         """
# --> 213         return self(kwargs, callbacks=callbacks)[self.output_key]
#     214
#     215     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     138         except (KeyboardInterrupt, Exception) as e:
#     139             run_manager.on_chain_error(e)
# --> 140             raise e
#     141         run_manager.on_chain_end(outputs)
#     142         return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     132         try:
#     133             outputs = (
# --> 134                 self._call(inputs, run_manager=run_manager)
#     135                 if new_arg_supported
#     136                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#      67         run_manager: Optional[CallbackManagerForChainRun] = None,
#      68     ) -> Dict[str, str]:
# ---> 69         response = self.generate([inputs], run_manager=run_manager)
#      70         return self.create_outputs(response)[0]
#      71
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#      77         """Generate LLM result from inputs."""
#      78         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# ---> 79         return self.llm.generate_prompt(
#      80             prompts, stop, callbacks=run_manager.get_child() if run_manager else None
#      81         )
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/base.py in generate_prompt(self, prompts, stop, callbacks)
#     141     ) -> LLMResult:
#     142         prompt_messages = [p.to_messages() for p in prompts]
# --> 143         return self.generate(prompt_messages, stop=stop, callbacks=callbacks)
#     144
#     145     async def agenerate_prompt(
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/base.py in generate(self, messages, stop, callbacks)
#      89         except (KeyboardInterrupt, Exception) as e:
#      90             run_manager.on_llm_error(e)
# ---> 91             raise e
#      92         llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      93         generations = [res.generations for res in results]
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/base.py in generate(self, messages, stop, callbacks)
#      81         )
#      82         try:
# ---> 83             results = [
#      84                 self._generate(m, stop=stop, run_manager=run_manager)
#      85                 if new_arg_supported
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/base.py in <listcomp>(.0)
#      82         try:
#      83             results = [
# ---> 84                 self._generate(m, stop=stop, run_manager=run_manager)
#      85                 if new_arg_supported
#      86                 else self._generate(m, stop=stop)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/openai.py in _generate(self, messages, stop, run_manager)
#     328             )
#     329             return ChatResult(generations=[ChatGeneration(message=message)])
# --> 330         response = self.completion_with_retry(messages=message_dicts, **params)
#     331         return self._create_chat_result(response)
#     332
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/openai.py in completion_with_retry(self, **kwargs)
#     283     def completion_with_retry(self, **kwargs: Any) -> Any:
#     284         """Use tenacity to retry the completion call."""
# --> 285         retry_decorator = self._create_retry_decorator()
#     286
#     287         @retry_decorator
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/openai.py in _create_retry_decorator(self)
#     272             wait=wait_exponential(multiplier=1, min=min_seconds, max=max_seconds),
#     273             retry=(
# --> 274                 retry_if_exception_type(openai.error.Timeout)
#     275                 | retry_if_exception_type(openai.error.APIError)
#     276                 | retry_if_exception_type(openai.error.APIConnectionError)
#
# AttributeError: module 'openai' has no attribute 'error'

# %%
# メモリ変数の取得
memory.load_memory_variables({})
