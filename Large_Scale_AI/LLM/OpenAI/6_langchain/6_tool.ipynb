# %% [markdown]
# # LangChainの準備

# %%
# パッケージのインストール
# !pip install langchain==0.0.181
# !pip install openai

# %%
# 環境変数の準備
import os
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# # Googleカスタム検索ツール

# %%
# 環境変数の準備
import os
os.environ["GOOGLE_CSE_ID"] = "5469ab30824494e97"
os.environ["GOOGLE_API_KEY"] = "AIzaSyBoMBDGvRPW55H_9lf-iy_fMWhlzeffd0s"

# %%
from langchain.agents import load_tools
from langchain.chat_models import ChatOpenAI

# ツールの準備
tools = load_tools(
    tool_names=["google-search"],
    llm=ChatOpenAI(temperature=0)
)

# %%
from langchain.chains.conversation.memory import ConversationBufferMemory

# メモリの作成
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# %%
from langchain.agents import initialize_agent

# エージェントの作成
agent = initialize_agent(
    agent="zero-shot-react-description",
    llm=ChatOpenAI(temperature=0),
    tools=tools,
    memory=memory,
    verbose=True
)

# %%
# エージェントの実行
agent.run("鬼滅の刃の作者の名前は？")

# %% [markdown]
# # Wolfram Alphaツール

# %%
# パッケージのインストール
# !pip install wolframalpha

# %%
# 環境変数の準備
import os
os.environ["WOLFRAM_ALPHA_APPID"] = "<Walfram_AlphaのAppID>"

# %%
from langchain.agents import load_tools

# ツールの準備
tools = load_tools(["wolfram-alpha"])

# %%
from langchain.chains.conversation.memory import ConversationBufferMemory

# メモリの作成
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# %%
from langchain.agents import initialize_agent
from langchain.chat_models import ChatOpenAI

# エージェントの作成
agent = initialize_agent(
    agent="zero-shot-react-description",
    llm=ChatOpenAI(temperature=0),
    tools=tools,
    memory=memory,
    verbose=True
)

# %%
# エージェントの実行
agent.run("東京都と大阪の距離は何km？")
